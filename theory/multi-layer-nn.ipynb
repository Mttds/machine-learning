# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
# A function to create a dataset.
from sklearn.datasets import make_blobs

# Output of plotting commands is displayed inline within the Jupyter notebook.
# %matplotlib inline 

# Set a seed so that the results are consistent.
np.random.seed(3)

# %% [markdown]
# More complex dataset where logistic regression is not enough to classify the data (single decision boundary)

# %%
fig, ax = plt.subplots()
xmin, xmax = -0.2, 1.4
x_line = np.arange(xmin, xmax, 0.1)
# Data points (observations) from two classes.
ax.scatter(0, 0, color="r")
ax.scatter(0, 1, color="b")
ax.scatter(1, 0, color="b")
ax.scatter(1, 1, color="r")
ax.set_xlim([xmin, xmax])
ax.set_ylim([-0.1, 1.1])
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
# Example of the lines which can be used as a decision boundary to separate two classes.
ax.plot(x_line, -1 * x_line + 1.5, color="black")
ax.plot(x_line, -1 * x_line + 0.5, color="black")
plt.plot()
# Out:
# []

# %% [markdown]
# <img src="img/nn_model_2_layers.png" style="width:1000px;">

# %% [markdown]
# The input and output layers of the neural network are the same as for one perceptron model, but there is a **hidden layer** now in between them. The training examples $x^{(i)}=\begin{bmatrix}x_1^{(i)} \\ x_2^{(i)}\end{bmatrix}$ from the input layer of size $n_x = 2$ are first fed into the hidden layer of size $n_h = 2$. They are simultaneously fed into the first perceptron with weights $W_1^{[1]}=\begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]}\end{bmatrix}$, bias  $b_1^{[1]}$; and into the second perceptron with weights $W_2^{[1]}=\begin{bmatrix}w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$, bias $b_2^{[1]}$. The integer in the square brackets $^{[1]}$ denotes the layer number, because there are two layers now with their own parameters and outputs, which need to be distinguished.
#
# \begin{align}
# z_1^{[1](i)} &= w_{1,1}^{[1]} x_1^{(i)} + w_{2,1}^{[1]} x_2^{(i)} + b_1^{[1]} = W_1^{[1]}x^{(i)} + b_1^{[1]},\\
# z_2^{[1](i)} &= w_{1,2}^{[1]} x_1^{(i)} + w_{2,2}^{[1]} x_2^{(i)} + b_2^{[1]} = W_2^{[1]}x^{(i)} + b_2^{[1]}.\tag{1}
# \end{align}
#
# These expressions for one training example $x^{(i)}$ can be rewritten in a matrix form :
#
# $$z^{[1](i)} = W^{[1]} x^{(i)} + b^{[1]},\tag{2}$$
#
# where
#
# &emsp; &emsp; $z^{[1](i)} = \begin{bmatrix}z_1^{[1](i)} \\ z_2^{[1](i)}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$;
#
# &emsp; &emsp; $W^{[1]} = \begin{bmatrix}W_1^{[1]} \\ W_2^{[1]}\end{bmatrix} =
# \begin{bmatrix}w_{1,1}^{[1]} & w_{2,1}^{[1]} \\ w_{1,2}^{[1]} & w_{2,2}^{[1]}\end{bmatrix}$ is matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$;
#
# &emsp; &emsp; $b^{[1]} = \begin{bmatrix}b_1^{[1]} \\ b_2^{[1]}\end{bmatrix}$ is vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$.

# %% [markdown]
# Next, the hidden layer activation function needs to be applied for each of the elements in the vector $z^{[1](i)}$. Various activation functions can be used here and in this model you will take the sigmoid function $\sigma\left(x\right) = \frac{1}{1 + e^{-x}}$. Remember that its derivative is $\frac{d\sigma}{dx} = \sigma\left(x\right)\left(1-\sigma\left(x\right)\right)$. The output of the hidden layer is a vector of size $\left(n_h \times 1\right) = \left(2 \times 1\right)$:
#
# $$a^{[1](i)} = \sigma\left(z^{[1](i)}\right) =
# \begin{bmatrix}\sigma\left(z_1^{[1](i)}\right) \\ \sigma\left(z_2^{[1](i)}\right)\end{bmatrix}.\tag{3}$$
#
# Then the hidden layer output gets fed into the output layer of size $n_y = 1$. This was covered in the previous lab, the only difference are: $a^{[1](i)}$ is taken instead of $x^{(i)}$ and layer notation $^{[2]}$ appears to identify all parameters and outputs:
#
# $$z^{[2](i)} = w_1^{[2]} a_1^{[1](i)} + w_2^{[2]} a_2^{[1](i)} + b^{[2]}= W^{[2]} a^{[1](i)} + b^{[2]},\tag{4}$$
#
# &emsp; &emsp; $z^{[2](i)}$ and $b^{[2]}$ are scalars for this model, as $\left(n_y \times 1\right) = \left(1 \times 1\right)$;
#
# &emsp; &emsp; $W^{[2]} = \begin{bmatrix}w_1^{[2]} & w_2^{[2]}\end{bmatrix}$ is vector of size $\left(n_y \times n_h\right) = \left(1 \times 2\right)$.
#
# Finally, the same sigmoid function is used as the output layer activation function:
#
# $$a^{[2](i)} = \sigma\left(z^{[2](i)}\right).\tag{5}$$
#
# Mathematically the two layer neural network model for each training example $x^{(i)}$ can be written with the expressions $(2) - (5)$. Let's rewrite them next to each other for convenience:
#
# \begin{align}
# z^{[1](i)} &= W^{[1]} x^{(i)} + b^{[1]},\\
# a^{[1](i)} &= \sigma\left(z^{[1](i)}\right),\\
# z^{[2](i)} &= W^{[2]} a^{[1](i)} + b^{[2]},\\
# a^{[2](i)} &= \sigma\left(z^{[2](i)}\right).\\
# \tag{6}
# \end{align}
#
# Note, that all of the parameters to be trained in the model are without $^{(i)}$ index - they are independent on the input data.

# %% [markdown]
# Finally, the predictions for some example $x^{(i)}$ can be made taking the output $a^{[2](i)}$ and calculating $\hat{y}$ as: $\hat{y} = \begin{cases} 1 & \mbox{if } a^{[2](i)} > 0.5, \\ 0 & \mbox{otherwise }. \end{cases}$.

# %% [markdown]
# <a name='2.2'></a>
# ### 2.2 - Neural Network Model with Two Layers for Multiple Training Examples

# %% [markdown]
# Similarly to the single perceptron model, $m$ training examples can be organised in a matrix $X$ of a shape ($2 \times m$), putting $x^{(i)}$ into columns. Then the model $(6)$ can be rewritten in terms of matrix multiplications:
#
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right),\\
# \tag{7}
# \end{align}
#
# where $b^{[1]}$ is broadcasted to the matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$ and $b^{[2]}$ to the vector of size $\left(n_y \times m\right) = \left(1 \times m\right)$. It would be a good exercise for you to have a look at the expressions $(7)$ and check that sizes of the matrices will actually match to perform required multiplications.
#
# You have derived expressions to perform forward propagation. Time to evaluate your model and train it.

# %% [markdown]
# <a name='2.3'></a>
# ### 2.3 - Cost Function and Training

# %% [markdown]
# For the evaluation of this simple neural network you can use the same cost function as for the single perceptron case - log loss function. Originally initialized weights were just some random values, now you need to perform training of the model: find such set of parameters $W^{[1]}$, $b^{[1]}$, $W^{[2]}$, $b^{[2]}$, that will minimize the cost function.
#
# Like in the previous example of a single perceptron neural network, the cost function can be written as:
#
# $$\mathcal{L}\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) = \frac{1}{m}\sum_{i=1}^{m} L\left(W^{[1]}, b^{[1]}, W^{[2]}, b^{[2]}\right) =  \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{[2](i)}\right) - (1-y^{(i)})\log\left(1- a^{[2](i)}\right)  \large  \right), \small\tag{8}$$
#
# where $y^{(i)} \in \{0,1\}$ are the original labels and $a^{[2](i)}$ are the continuous output values of the forward propagation step (elements of array $A^{[2]}$).
#
# To minimize it, you can use gradient descent, updating the parameters with the following expressions:
#
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} },\\
# \tag{9}
# \end{align}
#
# where $\alpha$ is the learning rate.

# %% [markdown]
# To perform training of the model you need to calculate now $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$, $\frac{\partial \mathcal{L} }{ \partial W^{[2]}}$, $\frac{\partial \mathcal{L} }{ \partial b^{[2]}}$.
#
# Let's start from the end of the neural network. You can rewrite here the corresponding expressions for $\frac{\partial \mathcal{L} }{ \partial W }$ and $\frac{\partial \mathcal{L} }{ \partial b }$ from the single perceptron neural network:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W } &=
# \frac{1}{m}\left(A-Y\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b } &=
# \frac{1}{m}\left(A-Y\right)\mathbf{1},\\
# \end{align}
#
# where $\mathbf{1}$ is just a ($m \times 1$) vector of ones. Your one perceptron is in the second layer now, so $W$ will be exchanged with $W^{[2]}$, $b$ with $b^{[2]}$, $A$ with $A^{[2]}$, $X$ with $A^{[1]}$:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1}.\\
# \tag{10}
# \end{align}

# %% [markdown]
# Let's now find $\frac{\partial \mathcal{L} }{ \partial W^{[1]}} =
# \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$. It was shown in the videos that $$\frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}}=\frac{1}{m}\sum_{i=1}^{m} \left(
# \left(a^{[2](i)} - y^{(i)}\right)
# w_1^{[2]}
# \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right)\tag{11}$$
#
# If you do this accurately for each of the elements $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$, you will get the following matrix:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \begin{bmatrix}
# \frac{\partial \mathcal{L} }{ \partial w_{1,1}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,1}^{[1]}} \\
# \frac{\partial \mathcal{L} }{ \partial w_{1,2}^{[1]}} & \frac{\partial \mathcal{L} }{ \partial w_{2,2}^{[1]}} \end{bmatrix}$$
# $$= \frac{1}{m}\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}\tag{12}$$

# %% [markdown]
# Looking at this, you can notice that all terms and indices somehow are very consistent, so it all can be unified into a matrix form. And that's true! $\left(W^{[2]}\right)^T = \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}$ of size $\left(n_h \times n_y\right) = \left(2 \times 1\right)$ can be multiplied with the vector $A^{[2]} - Y$ of size $\left(n_y \times m\right) = \left(1 \times m\right)$, resulting in a matrix of size $\left(n_h \times m\right) = \left(2 \times m\right)$:
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)=
# \begin{bmatrix}w_1^{[2]} \\ w_2^{[2]}\end{bmatrix}
# \begin{bmatrix}\left(a^{[2](1)} - y^{(1)}\right) &  \cdots & \left(a^{[2](m)} - y^{(m)}\right)\end{bmatrix}
# =\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]} \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]} & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \end{bmatrix}$$.
#
# Now taking matrix $A^{[1]}$ of the same size $\left(n_h \times m\right) = \left(2 \times m\right)$,
#
# $$A^{[1]}
# =\begin{bmatrix}
# a_1^{[1](1)} & \cdots & a_1^{[1](m)} \\
# a_2^{[1](1)} & \cdots & a_2^{[1](m)} \end{bmatrix},$$
#
# you can calculate:
#
# $$A^{[1]}\cdot\left(1-A^{[1]}\right)
# =\begin{bmatrix}
# a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right) & \cdots & a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right) \\
# a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right) & \cdots & a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right) \end{bmatrix},$$
#
# where "$\cdot$" denotes **element by element** multiplication.

# %% [markdown]
# With the element by element multiplication,
#
# $$\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)=\begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}.$$
#
# If you perform matrix multiplication with $X^T$ of size $\left(m \times n_x\right) = \left(m \times 2\right)$, you will get matrix of size $\left(n_h \times n_x\right) = \left(2 \times 2\right)$:
#
# $$\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T =
# \begin{bmatrix}
# \left(a^{[2](1)} - y^{(1)}\right) w_1^{[2]}\left(a_1^{[1](1)}\left(1 - a_1^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_1^{[2]}\left(a_1^{[1](m)}\left(1 - a_1^{[1](m)}\right)\right) \\
# \left(a^{[2](1)} - y^{(1)}\right) w_2^{[2]}\left(a_2^{[1](1)}\left(1 - a_2^{[1](1)}\right)\right) & \cdots & \left(a^{[2](m)} - y^{(m)}\right) w_2^{[2]} \left(a_2^{[1](m)}\left(1 - a_2^{[1](m)}\right)\right) \end{bmatrix}
# \begin{bmatrix}
# x_1^{(1)} & x_2^{(1)} \\
# \cdots & \cdots \\
# x_1^{(m)} & x_2^{(m)}
# \end{bmatrix}$$
# $$=\begin{bmatrix}
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1 - a_1^{[1](i)}\right) \right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_1^{[2]} \left(a_1^{[1](i)}\left(1-a_1^{[1](i)}\right)\right)
# x_2^{(i)}\right)  \\
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_1^{(i)}\right) &
# \sum_{i=1}^{m} \left( \left(a^{[2](i)} - y^{(i)}\right) w_2^{[2]} \left(a_2^{[1](i)}\left(1-a_2^{[1](i)}\right)\right)
# x_2^{(i)}\right)\end{bmatrix}$$
#
# This is exactly like in the expression $(12)$! So, $\frac{\partial \mathcal{L} }{ \partial W^{[1]}}$ can be written as a mixture of multiplications:
#
# $$\frac{\partial \mathcal{L} }{ \partial W^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T\tag{13},$$
#
# where "$\cdot$" denotes element by element multiplications.

# %% [markdown]
# Vector $\frac{\partial \mathcal{L} }{ \partial b^{[1]}}$ can be found very similarly, but the last terms in the chain rule will be equal to $1$, i.e. $\frac{\partial z_1^{[1](i)}}{ \partial b_1^{[1]}} = 1$. Thus,
#
# $$\frac{\partial \mathcal{L} }{ \partial b^{[1]}} = \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\tag{14}$$
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.
#
# Expressions $(10)$, $(13)$ and $(14)$ can be used for the parameters update $(9)$ performing backward propagation:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1},\\
# \tag{15}
# \end{align}
#
# where $\mathbf{1}$ is a ($m \times 1$) vector of ones.

# %%
m = 2000
samples, labels = make_blobs(n_samples=m, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0) | (labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 0
X = np.transpose(samples)
Y = labels.reshape((1, m))

plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

print ('The shape of X is: ' + str(X.shape))
print ('The shape of Y is: ' + str(Y.shape))
print ('I have m = %d training examples!' % (m))
# Out:
# The shape of X is: (2, 2000)
# The shape of Y is: (1, 2000)
# I have m = 2000 training examples!

# %%
def sigmoid(z):
    res = 1 / (1 + np.exp(-z))    
    return res

# %%
print("sigmoid(-2) = " + str(sigmoid(-2)))
print("sigmoid(0) = " + str(sigmoid(0)))
print("sigmoid(3.5) = " + str(sigmoid(3.5)))
# Out:
# sigmoid(-2) = 0.11920292202211755
# sigmoid(0) = 0.5
# sigmoid(3.5) = 0.9706877692486436

# %%
def layer_sizes(X, Y):
    """
    Arguments:
    X -- input dataset of shape (input size, number of examples)
    Y -- labels of shape (output size, number of examples)
    
    Returns:
    n_x -- the size of the input layer
    n_h -- the size of the hidden layer
    n_y -- the size of the output layer
    """
    # Size of input layer.
    n_x = X.shape[0]
    # Size of hidden layer.
    n_h = 2
    # Size of output layer.
    n_y = Y.shape[0] 
    return (n_x, n_h, n_y)

# %%
(n_x, n_h, n_y) = layer_sizes(X, Y)
print("The size of the input layer is: n_x = " + str(n_x))
print("The size of the hidden layer is: n_h = " + str(n_h))
print("The size of the output layer is: n_y = " + str(n_y))
# Out:
# The size of the input layer is: n_x = 2
# The size of the hidden layer is: n_h = 2
# The size of the output layer is: n_y = 1

# %%
def initialize_parameters(n_x, n_h, n_y):
    """
    Argument:
    n_x -- size of the input layer
    n_h -- size of the hidden layer
    n_y -- size of the output layer
    
    Returns:
    params -- python dictionary containing your parameters:
                    W1 -- weight matrix of shape (n_h, n_x)
                    b1 -- bias vector of shape (n_h, 1)
                    W2 -- weight matrix of shape (n_y, n_h)
                    b2 -- bias vector of shape (n_y, 1)
    """
    W1 = np.random.randn(n_h, n_x) * 0.01
    b1 = np.zeros((n_h, 1))
    W2 = np.random.randn(n_y, n_h) * 0.01
    b2 = np.zeros((n_y, 1))
    
    assert (W1.shape == (n_h, n_x))
    assert (b1.shape == (n_h, 1))
    assert (W2.shape == (n_y, n_h))
    assert (b2.shape == (n_y, 1))
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters = initialize_parameters(n_x, n_h, n_y)

print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))
# Out:
# W1 = [[ 0.01788628  0.0043651 ]
#  [ 0.00096497 -0.01863493]]
# b1 = [[0.]
#  [0.]]
# W2 = [[-0.00277388 -0.00354759]]
# b2 = [[0.]]

# %% [markdown]
# \begin{align}
# Z^{[1]} &= W^{[1]} X + b^{[1]},\\
# A^{[1]} &= \sigma\left(Z^{[1]}\right),\\
# Z^{[2]} &= W^{[2]} A^{[1]} + b^{[2]},\\
# A^{[2]} &= \sigma\left(Z^{[2]}\right).\\
# \end{align}

# %%
def forward_propagation(X, parameters):
    """
    Argument:
    X -- input data of size (n_x, m)
    parameters -- python dictionary containing your parameters (output of initialization function)
    
    Returns:
    A2 -- the sigmoid output of the second activation
    cache -- python dictionary containing Z1, A1, Z2, A2 
    (that simplifies the calculations in the back propagation step)
    """
    # Retrieve each parameter from the dictionary "parameters".
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    # Implement forward propagation to calculate A2.
    Z1 = W1 @ X + b1
    A1 = sigmoid(Z1)
    Z2 = W2 @ A1 + b2
    A2 = sigmoid(Z2)
    
    assert(A2.shape == (n_y, X.shape[1]))

    cache = {"Z1": Z1,
             "A1": A1,
             "Z2": Z2,
             "A2": A2}
    
    return A2, cache

# %%
A2, cache = forward_propagation(X, parameters)

print(A2)
# Out:
# [[0.49920157 0.49922234 0.49921223 ... 0.49921215 0.49921043 0.49920665]]

# %% [markdown]
# Define the cost function to minimize (logloss).
#
# $$\mathcal{L}\left(W, b\right)  = \frac{1}{m}\sum_{i=1}^{m}  \large\left(\small - y^{(i)}\log\left(a^{(i)}\right) - (1-y^{(i)})\log\left(1- a^{(i)}\right)  \large  \right) \small.$$

# %%
def compute_cost(A2, Y):
    """
    Computes the cost function as a log loss
    
    Arguments:
    A2 -- The output of the neural network of shape (1, number of examples)
    Y -- "true" labels vector of shape (1, number of examples)
    
    Returns:
    cost -- log loss
    
    """
    # Number of examples.
    m = Y.shape[1]
    logloss = -np.multiply(Y, np.log(A2)) -np.multiply((1 - Y), np.log(1 - A2))
    cost = 1/m * np.sum(logloss)
    assert(isinstance(cost, float))
    
    return cost

# %%
print("cost = " + str(compute_cost(A2, Y)))
# Out:
# cost = 0.6931477703826823

# %% [markdown]
# Calculate partial derivatives to implement backward prop:
#
# \begin{align}
# \frac{\partial \mathcal{L} }{ \partial W^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\left(A^{[1]}\right)^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[2]} } &=
# \frac{1}{m}\left(A^{[2]}-Y\right)\mathbf{1},\\
# \frac{\partial \mathcal{L} }{ \partial W^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)X^T,\\
# \frac{\partial \mathcal{L} }{ \partial b^{[1]}} &= \frac{1}{m}\left(\left(W^{[2]}\right)^T \left(A^{[2]} - Y\right)\cdot \left(A^{[1]}\cdot\left(1-A^{[1]}\right)\right)\right)\mathbf{1}.\\
# \end{align}

# %%
def backward_propagation(parameters, cache, X, Y):
    """
    Implements the backward propagation, calculating gradients
    
    Arguments:
    parameters -- python dictionary containing our parameters 
    cache -- python dictionary containing Z1, A1, Z2, A2
    X -- input data of shape (n_x, number of examples)
    Y -- "true" labels vector of shape (n_y, number of examples)
    
    Returns:
    grads -- python dictionary containing gradients with respect to different parameters
    """
    m = X.shape[1]
    
    # First, retrieve W from the dictionary "parameters".
    W1 = parameters["W1"]
    W2 = parameters["W2"]
    
    # Retrieve also A1 and A2 from dictionary "cache".
    A1 = cache["A1"]
    A2 = cache["A2"]
    
    # Backward propagation: calculate partial derivatives denoted as dW1, db1, dW2, db2 for simplicity. 
    dZ2 = A2 - Y
    dW2 = 1/m * np.dot(dZ2, A1.T)
    db2 = 1/m * np.sum(dZ2, axis = 1, keepdims = True)
    dZ1 = np.dot(W2.T, dZ2) * A1 * (1 - A1)
    dW1 = 1/m * np.dot(dZ1, X.T)
    db1 = 1/m * np.sum(dZ1, axis = 1, keepdims = True)
    
    grads = {"dW1": dW1,
             "db1": db1,
             "dW2": dW2,
             "db2": db2}
    
    return grads

grads = backward_propagation(parameters, cache, X, Y)

print("dW1 = " + str(grads["dW1"]))
print("db1 = " + str(grads["db1"]))
print("dW2 = " + str(grads["dW2"]))
print("db2 = " + str(grads["db2"]))
# Out:
# dW1 = [[-1.49856632e-05  1.67791519e-05]
#  [-2.12394543e-05  2.43895135e-05]]
# db1 = [[5.11207671e-07]
#  [7.06236219e-07]]
# dW2 = [[-0.00032641 -0.0002606 ]]
# db2 = [[-0.00078732]]

# %% [markdown]
# \begin{align}
# W^{[1]} &= W^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[1]} },\\
# b^{[1]} &= b^{[1]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[1]} },\\
# W^{[2]} &= W^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial W^{[2]} },\\
# b^{[2]} &= b^{[2]} - \alpha \frac{\partial \mathcal{L} }{ \partial b^{[2]} }.\\
# \end{align}

# %%
def update_parameters(parameters, grads, learning_rate=1.2):
    """
    Updates parameters using the gradient descent update rule
    
    Arguments:
    parameters -- python dictionary containing parameters 
    grads -- python dictionary containing gradients
    learning_rate -- learning rate for gradient descent
    
    Returns:
    parameters -- python dictionary containing updated parameters 
    """
    # Retrieve each parameter from the dictionary "parameters".
    W1 = parameters['W1']
    b1 = parameters['b1']
    W2 = parameters['W2']
    b2 = parameters['b2']
    
    # Retrieve each gradient from the dictionary "grads".
    dW1 = grads['dW1']
    db1 = grads['db1']
    dW2 = grads['dW2']
    db2 = grads['db2']
    
    # Update rule for each parameter.
    W1 = W1 - np.multiply(learning_rate, dW1)
    b1 = b1 - np.multiply(learning_rate, db1)
    W2 = W2 - np.multiply(learning_rate, dW2)
    b2 = b2 - np.multiply(learning_rate, db2)
    
    parameters = {"W1": W1,
                  "b1": b1,
                  "W2": W2,
                  "b2": b2}
    
    return parameters

# %%
parameters_updated = update_parameters(parameters, grads)

print("W1 updated = " + str(parameters_updated["W1"]))
print("b1 updated = " + str(parameters_updated["b1"]))
print("W2 updated = " + str(parameters_updated["W2"]))
print("b2 updated = " + str(parameters_updated["b2"]))
# Out:
# W1 updated = [[ 0.01790427  0.00434496]
#  [ 0.00099046 -0.01866419]]
# b1 updated = [[-6.13449205e-07]
#  [-8.47483463e-07]]
# W2 updated = [[-0.00238219 -0.00323487]]
# b2 updated = [[0.00094478]]

# %%
def nn_model(X, Y, n_h, num_iterations=10, learning_rate=1.2, print_cost=False):
    """
    Arguments:
    X -- dataset of shape (n_x, number of examples)
    Y -- labels of shape (n_y, number of examples)
    num_iterations -- number of iterations in the loop
    learning_rate -- learning rate parameter for gradient descent
    print_cost -- if True, print the cost every iteration
    
    Returns:
    parameters -- parameters learnt by the model. They can then be used to predict.
    """
    
    n_x = layer_sizes(X, Y)[0]
    n_y = layer_sizes(X, Y)[2]
    
    # Initialize parameters.
    parameters = initialize_parameters(n_x, n_h, n_y)
    
    # Loop.
    for i in range(0, num_iterations):
        # Forward propagation. Inputs: "X, parameters". Outputs: "A2, cache".
        A2, cache = forward_propagation(X, parameters)
        
        # Cost function. Inputs: "A2, Y". Outputs: "cost".
        cost = compute_cost(A2, Y)
        
        # Backpropagation. Inputs: "parameters, cache, X, Y". Outputs: "grads".
        grads = backward_propagation(parameters, cache, X, Y)
        
        # Gradient descent parameter update. Inputs: "parameters, grads, learning_rate". Outputs: "parameters".
        parameters = update_parameters(parameters, grads, learning_rate)
        
        # Print the cost every iteration.
        if print_cost:
            print ("Cost after iteration %i: %f" %(i, cost))

    return parameters

# %%
parameters = nn_model(X, Y, n_h=2, num_iterations=3000, learning_rate=1.2, print_cost=True)
print("W1 = " + str(parameters["W1"]))
print("b1 = " + str(parameters["b1"]))
print("W2 = " + str(parameters["W2"]))
print("b2 = " + str(parameters["b2"]))

W1 = parameters["W1"]
b1 = parameters["b1"]
W2 = parameters["W2"]
b2 = parameters["b2"]
# Out:
# Cost after iteration 0: 0.693148
# Cost after iteration 1: 0.693147
# Cost after iteration 2: 0.693147
# Cost after iteration 3: 0.693147
# Cost after iteration 4: 0.693147
# Cost after iteration 5: 0.693147
# Cost after iteration 6: 0.693147
# Cost after iteration 7: 0.693147
# Cost after iteration 8: 0.693147
# Cost after iteration 9: 0.693147
# Cost after iteration 10: 0.693147
# Cost after iteration 11: 0.693147
# Cost after iteration 12: 0.693147
# Cost after iteration 13: 0.693147
# Cost after iteration 14: 0.693147
# Cost after iteration 15: 0.693147
# Cost after iteration 16: 0.693147
# Cost after iteration 17: 0.693147
# Cost after iteration 18: 0.693147
# Cost after iteration 19: 0.693147
# Cost after iteration 20: 0.693147
# Cost after iteration 21: 0.693147
# Cost after iteration 22: 0.693146
# Cost after iteration 23: 0.693146
# Cost after iteration 24: 0.693146
# Cost after iteration 25: 0.693146
# Cost after iteration 26: 0.693146
# Cost after iteration 27: 0.693146
# Cost after iteration 28: 0.693146
# Cost after iteration 29: 0.693146
# Cost after iteration 30: 0.693146
# Cost after iteration 31: 0.693146
# Cost after iteration 32: 0.693146
# Cost after iteration 33: 0.693146
# Cost after iteration 34: 0.693146
# Cost after iteration 35: 0.693146
# Cost after iteration 36: 0.693146
# Cost after iteration 37: 0.693146
# Cost after iteration 38: 0.693146
# Cost after iteration 39: 0.693146
# Cost after iteration 40: 0.693146
# Cost after iteration 41: 0.693146
# Cost after iteration 42: 0.693146
# Cost after iteration 43: 0.693146
# Cost after iteration 44: 0.693146
# Cost after iteration 45: 0.693146
# Cost after iteration 46: 0.693146
# Cost after iteration 47: 0.693146
# Cost after iteration 48: 0.693146
# Cost after iteration 49: 0.693146
# Cost after iteration 50: 0.693146
# Cost after iteration 51: 0.693146
# Cost after iteration 52: 0.693146
# Cost after iteration 53: 0.693145
# Cost after iteration 54: 0.693145
# Cost after iteration 55: 0.693145
# Cost after iteration 56: 0.693145
# Cost after iteration 57: 0.693145
# Cost after iteration 58: 0.693145
# Cost after iteration 59: 0.693145
# Cost after iteration 60: 0.693145
# Cost after iteration 61: 0.693145
# Cost after iteration 62: 0.693145
# Cost after iteration 63: 0.693145
# Cost after iteration 64: 0.693145
# Cost after iteration 65: 0.693145
# Cost after iteration 66: 0.693145
# Cost after iteration 67: 0.693145
# Cost after iteration 68: 0.693145
# Cost after iteration 69: 0.693145
# Cost after iteration 70: 0.693145
# Cost after iteration 71: 0.693145
# Cost after iteration 72: 0.693145
# Cost after iteration 73: 0.693144
# Cost after iteration 74: 0.693144
# Cost after iteration 75: 0.693144
# Cost after iteration 76: 0.693144
# Cost after iteration 77: 0.693144
# Cost after iteration 78: 0.693144
# Cost after iteration 79: 0.693144
# Cost after iteration 80: 0.693144
# Cost after iteration 81: 0.693144
# Cost after iteration 82: 0.693144
# Cost after iteration 83: 0.693144
# Cost after iteration 84: 0.693144
# Cost after iteration 85: 0.693144
# Cost after iteration 86: 0.693144
# Cost after iteration 87: 0.693144
# Cost after iteration 88: 0.693143
# Cost after iteration 89: 0.693143
# Cost after iteration 90: 0.693143
# Cost after iteration 91: 0.693143
# Cost after iteration 92: 0.693143
# Cost after iteration 93: 0.693143
# Cost after iteration 94: 0.693143
# Cost after iteration 95: 0.693143
# Cost after iteration 96: 0.693143
# Cost after iteration 97: 0.693143
# Cost after iteration 98: 0.693143
# Cost after iteration 99: 0.693142
# Cost after iteration 100: 0.693142
# Cost after iteration 101: 0.693142
# Cost after iteration 102: 0.693142
# Cost after iteration 103: 0.693142
# Cost after iteration 104: 0.693142
# Cost after iteration 105: 0.693142
# Cost after iteration 106: 0.693142
# Cost after iteration 107: 0.693142
# Cost after iteration 108: 0.693142
# Cost after iteration 109: 0.693141
# Cost after iteration 110: 0.693141
# Cost after iteration 111: 0.693141
# Cost after iteration 112: 0.693141
# Cost after iteration 113: 0.693141
# Cost after iteration 114: 0.693141
# Cost after iteration 115: 0.693141
# Cost after iteration 116: 0.693140
# Cost after iteration 117: 0.693140
# Cost after iteration 118: 0.693140
# Cost after iteration 119: 0.693140
# Cost after iteration 120: 0.693140
# Cost after iteration 121: 0.693140
# Cost after iteration 122: 0.693140
# Cost after iteration 123: 0.693139
# Cost after iteration 124: 0.693139
# Cost after iteration 125: 0.693139
# Cost after iteration 126: 0.693139
# Cost after iteration 127: 0.693139
# Cost after iteration 128: 0.693139
# Cost after iteration 129: 0.693138
# Cost after iteration 130: 0.693138
# Cost after iteration 131: 0.693138
# Cost after iteration 132: 0.693138
# Cost after iteration 133: 0.693138
# Cost after iteration 134: 0.693137
# Cost after iteration 135: 0.693137
# Cost after iteration 136: 0.693137
# Cost after iteration 137: 0.693137
# Cost after iteration 138: 0.693137
# Cost after iteration 139: 0.693136
# Cost after iteration 140: 0.693136
# Cost after iteration 141: 0.693136
# Cost after iteration 142: 0.693136
# Cost after iteration 143: 0.693135
# Cost after iteration 144: 0.693135
# Cost after iteration 145: 0.693135
# Cost after iteration 146: 0.693135
# Cost after iteration 147: 0.693134
# Cost after iteration 148: 0.693134
# Cost after iteration 149: 0.693134
# Cost after iteration 150: 0.693134
# Cost after iteration 151: 0.693133
# Cost after iteration 152: 0.693133
# Cost after iteration 153: 0.693133
# Cost after iteration 154: 0.693132
# Cost after iteration 155: 0.693132
# Cost after iteration 156: 0.693132
# Cost after iteration 157: 0.693131
# Cost after iteration 158: 0.693131
# Cost after iteration 159: 0.693131
# Cost after iteration 160: 0.693130
# Cost after iteration 161: 0.693130
# Cost after iteration 162: 0.693130
# Cost after iteration 163: 0.693129
# Cost after iteration 164: 0.693129
# Cost after iteration 165: 0.693128
# Cost after iteration 166: 0.693128
# Cost after iteration 167: 0.693128
# Cost after iteration 168: 0.693127
# Cost after iteration 169: 0.693127
# Cost after iteration 170: 0.693126
# Cost after iteration 171: 0.693126
# Cost after iteration 172: 0.693125
# Cost after iteration 173: 0.693125
# Cost after iteration 174: 0.693124
# Cost after iteration 175: 0.693124
# Cost after iteration 176: 0.693123
# Cost after iteration 177: 0.693123
# Cost after iteration 178: 0.693122
# Cost after iteration 179: 0.693121
# Cost after iteration 180: 0.693121
# Cost after iteration 181: 0.693120
# Cost after iteration 182: 0.693120
# Cost after iteration 183: 0.693119
# Cost after iteration 184: 0.693118
# Cost after iteration 185: 0.693118
# Cost after iteration 186: 0.693117
# Cost after iteration 187: 0.693116
# Cost after iteration 188: 0.693115
# Cost after iteration 189: 0.693115
# Cost after iteration 190: 0.693114
# Cost after iteration 191: 0.693113
# Cost after iteration 192: 0.693112
# Cost after iteration 193: 0.693111
# Cost after iteration 194: 0.693110
# Cost after iteration 195: 0.693110
# Cost after iteration 196: 0.693109
# Cost after iteration 197: 0.693108
# Cost after iteration 198: 0.693107
# Cost after iteration 199: 0.693106
# Cost after iteration 200: 0.693104
# Cost after iteration 201: 0.693103
# Cost after iteration 202: 0.693102
# Cost after iteration 203: 0.693101
# Cost after iteration 204: 0.693100
# Cost after iteration 205: 0.693098
# Cost after iteration 206: 0.693097
# Cost after iteration 207: 0.693096
# Cost after iteration 208: 0.693094
# Cost after iteration 209: 0.693093
# Cost after iteration 210: 0.693091
# Cost after iteration 211: 0.693089
# Cost after iteration 212: 0.693088
# Cost after iteration 213: 0.693086
# Cost after iteration 214: 0.693084
# Cost after iteration 215: 0.693082
# Cost after iteration 216: 0.693080
# Cost after iteration 217: 0.693078
# Cost after iteration 218: 0.693076
# Cost after iteration 219: 0.693073
# Cost after iteration 220: 0.693071
# Cost after iteration 221: 0.693068
# Cost after iteration 222: 0.693066
# Cost after iteration 223: 0.693063
# Cost after iteration 224: 0.693060
# Cost after iteration 225: 0.693057
# Cost after iteration 226: 0.693053
# Cost after iteration 227: 0.693050
# Cost after iteration 228: 0.693046
# Cost after iteration 229: 0.693042
# Cost after iteration 230: 0.693038
# Cost after iteration 231: 0.693034
# Cost after iteration 232: 0.693029
# Cost after iteration 233: 0.693024
# Cost after iteration 234: 0.693018
# Cost after iteration 235: 0.693013
# Cost after iteration 236: 0.693006
# Cost after iteration 237: 0.693000
# Cost after iteration 238: 0.692993
# Cost after iteration 239: 0.692985
# Cost after iteration 240: 0.692977
# Cost after iteration 241: 0.692968
# Cost after iteration 242: 0.692958
# Cost after iteration 243: 0.692948
# Cost after iteration 244: 0.692936
# Cost after iteration 245: 0.692924
# Cost after iteration 246: 0.692910
# Cost after iteration 247: 0.692896
# Cost after iteration 248: 0.692879
# Cost after iteration 249: 0.692861
# Cost after iteration 250: 0.692841
# Cost after iteration 251: 0.692819
# Cost after iteration 252: 0.692795
# Cost after iteration 253: 0.692768
# Cost after iteration 254: 0.692737
# Cost after iteration 255: 0.692703
# Cost after iteration 256: 0.692664
# Cost after iteration 257: 0.692621
# Cost after iteration 258: 0.692572
# Cost after iteration 259: 0.692516
# Cost after iteration 260: 0.692452
# Cost after iteration 261: 0.692379
# Cost after iteration 262: 0.692294
# Cost after iteration 263: 0.692198
# Cost after iteration 264: 0.692085
# Cost after iteration 265: 0.691955
# Cost after iteration 266: 0.691804
# Cost after iteration 267: 0.691627
# Cost after iteration 268: 0.691420
# Cost after iteration 269: 0.691177
# Cost after iteration 270: 0.690893
# Cost after iteration 271: 0.690559
# Cost after iteration 272: 0.690166
# Cost after iteration 273: 0.689705
# Cost after iteration 274: 0.689165
# Cost after iteration 275: 0.688534
# Cost after iteration 276: 0.687800
# Cost after iteration 277: 0.686949
# Cost after iteration 278: 0.685968
# Cost after iteration 279: 0.684848
# Cost after iteration 280: 0.683576
# Cost after iteration 281: 0.682146
# Cost after iteration 282: 0.680554
# Cost after iteration 283: 0.678799
# Cost after iteration 284: 0.676884
# Cost after iteration 285: 0.674819
# Cost after iteration 286: 0.672613
# Cost after iteration 287: 0.670281
# Cost after iteration 288: 0.667841
# Cost after iteration 289: 0.665312
# Cost after iteration 290: 0.662711
# Cost after iteration 291: 0.660059
# Cost after iteration 292: 0.657374
# Cost after iteration 293: 0.654673
# Cost after iteration 294: 0.651972
# Cost after iteration 295: 0.649284
# Cost after iteration 296: 0.646622
# Cost after iteration 297: 0.643994
# Cost after iteration 298: 0.641409
# Cost after iteration 299: 0.638873
# Cost after iteration 300: 0.636390
# Cost after iteration 301: 0.633963
# Cost after iteration 302: 0.631593
# Cost after iteration 303: 0.629280
# Cost after iteration 304: 0.627023
# Cost after iteration 305: 0.624820
# Cost after iteration 306: 0.622668
# Cost after iteration 307: 0.620561
# Cost after iteration 308: 0.618495
# Cost after iteration 309: 0.616463
# Cost after iteration 310: 0.614459
# Cost after iteration 311: 0.612473
# Cost after iteration 312: 0.610496
# Cost after iteration 313: 0.608516
# Cost after iteration 314: 0.606517
# Cost after iteration 315: 0.604482
# Cost after iteration 316: 0.602387
# Cost after iteration 317: 0.600206
# Cost after iteration 318: 0.597905
# Cost after iteration 319: 0.595447
# Cost after iteration 320: 0.592794
# Cost after iteration 321: 0.589905
# Cost after iteration 322: 0.586741
# Cost after iteration 323: 0.583268
# Cost after iteration 324: 0.579459
# Cost after iteration 325: 0.575296
# Cost after iteration 326: 0.570775
# Cost after iteration 327: 0.565905
# Cost after iteration 328: 0.560704
# Cost after iteration 329: 0.555206
# Cost after iteration 330: 0.549448
# Cost after iteration 331: 0.543474
# Cost after iteration 332: 0.537330
# Cost after iteration 333: 0.531060
# Cost after iteration 334: 0.524707
# Cost after iteration 335: 0.518309
# Cost after iteration 336: 0.511901
# Cost after iteration 337: 0.505512
# Cost after iteration 338: 0.499169
# Cost after iteration 339: 0.492893
# Cost after iteration 340: 0.486702
# Cost after iteration 341: 0.480611
# Cost after iteration 342: 0.474631
# Cost after iteration 343: 0.468771
# Cost after iteration 344: 0.463038
# Cost after iteration 345: 0.457437
# Cost after iteration 346: 0.451972
# Cost after iteration 347: 0.446645
# Cost after iteration 348: 0.441456
# Cost after iteration 349: 0.436406
# Cost after iteration 350: 0.431493
# Cost after iteration 351: 0.426717
# Cost after iteration 352: 0.422076
# Cost after iteration 353: 0.417566
# Cost after iteration 354: 0.413186
# Cost after iteration 355: 0.408933
# Cost after iteration 356: 0.404803
# Cost after iteration 357: 0.400793
# Cost after iteration 358: 0.396900
# Cost after iteration 359: 0.393121
# Cost after iteration 360: 0.389451
# Cost after iteration 361: 0.385889
# Cost after iteration 362: 0.382429
# Cost after iteration 363: 0.379069
# Cost after iteration 364: 0.375806
# Cost after iteration 365: 0.372635
# Cost after iteration 366: 0.369555
# Cost after iteration 367: 0.366561
# Cost after iteration 368: 0.363652
# Cost after iteration 369: 0.360823
# Cost after iteration 370: 0.358072
# Cost after iteration 371: 0.355396
# Cost after iteration 372: 0.352792
# Cost after iteration 373: 0.350259
# Cost after iteration 374: 0.347792
# Cost after iteration 375: 0.345391
# Cost after iteration 376: 0.343052
# Cost after iteration 377: 0.340773
# Cost after iteration 378: 0.338553
# Cost after iteration 379: 0.336388
# Cost after iteration 380: 0.334277
# Cost after iteration 381: 0.332219
# Cost after iteration 382: 0.330210
# Cost after iteration 383: 0.328250
# Cost after iteration 384: 0.326336
# Cost after iteration 385: 0.324467
# Cost after iteration 386: 0.322642
# Cost after iteration 387: 0.320858
# Cost after iteration 388: 0.319114
# Cost after iteration 389: 0.317410
# Cost after iteration 390: 0.315743
# Cost after iteration 391: 0.314112
# Cost after iteration 392: 0.312516
# Cost after iteration 393: 0.310954
# Cost after iteration 394: 0.309424
# Cost after iteration 395: 0.307926
# Cost after iteration 396: 0.306458
# Cost after iteration 397: 0.305020
# Cost after iteration 398: 0.303610
# Cost after iteration 399: 0.302227
# Cost after iteration 400: 0.300871
# Cost after iteration 401: 0.299540
# Cost after iteration 402: 0.298234
# Cost after iteration 403: 0.296951
# Cost after iteration 404: 0.295692
# Cost after iteration 405: 0.294456
# Cost after iteration 406: 0.293240
# Cost after iteration 407: 0.292046
# Cost after iteration 408: 0.290872
# Cost after iteration 409: 0.289718
# Cost after iteration 410: 0.288582
# Cost after iteration 411: 0.287465
# Cost after iteration 412: 0.286366
# Cost after iteration 413: 0.285284
# Cost after iteration 414: 0.284219
# Cost after iteration 415: 0.283170
# Cost after iteration 416: 0.282136
# Cost after iteration 417: 0.281118
# Cost after iteration 418: 0.280114
# Cost after iteration 419: 0.279125
# Cost after iteration 420: 0.278150
# Cost after iteration 421: 0.277188
# Cost after iteration 422: 0.276239
# Cost after iteration 423: 0.275303
# Cost after iteration 424: 0.274379
# Cost after iteration 425: 0.273467
# Cost after iteration 426: 0.272566
# Cost after iteration 427: 0.271677
# Cost after iteration 428: 0.270799
# Cost after iteration 429: 0.269932
# Cost after iteration 430: 0.269075
# Cost after iteration 431: 0.268228
# Cost after iteration 432: 0.267390
# Cost after iteration 433: 0.266563
# Cost after iteration 434: 0.265745
# Cost after iteration 435: 0.264935
# Cost after iteration 436: 0.264135
# Cost after iteration 437: 0.263343
# Cost after iteration 438: 0.262560
# Cost after iteration 439: 0.261784
# Cost after iteration 440: 0.261017
# Cost after iteration 441: 0.260258
# Cost after iteration 442: 0.259506
# Cost after iteration 443: 0.258761
# Cost after iteration 444: 0.258024
# Cost after iteration 445: 0.257294
# Cost after iteration 446: 0.256571
# Cost after iteration 447: 0.255855
# Cost after iteration 448: 0.255145
# Cost after iteration 449: 0.254442
# Cost after iteration 450: 0.253746
# Cost after iteration 451: 0.253055
# Cost after iteration 452: 0.252371
# Cost after iteration 453: 0.251693
# Cost after iteration 454: 0.251021
# Cost after iteration 455: 0.250354
# Cost after iteration 456: 0.249694
# Cost after iteration 457: 0.249039
# Cost after iteration 458: 0.248389
# Cost after iteration 459: 0.247745
# Cost after iteration 460: 0.247107
# Cost after iteration 461: 0.246474
# Cost after iteration 462: 0.245846
# Cost after iteration 463: 0.245223
# Cost after iteration 464: 0.244605
# Cost after iteration 465: 0.243992
# Cost after iteration 466: 0.243385
# Cost after iteration 467: 0.242782
# Cost after iteration 468: 0.242184
# Cost after iteration 469: 0.241591
# Cost after iteration 470: 0.241003
# Cost after iteration 471: 0.240420
# Cost after iteration 472: 0.239841
# Cost after iteration 473: 0.239267
# Cost after iteration 474: 0.238697
# Cost after iteration 475: 0.238133
# Cost after iteration 476: 0.237572
# Cost after iteration 477: 0.237017
# Cost after iteration 478: 0.236466
# Cost after iteration 479: 0.235919
# Cost after iteration 480: 0.235377
# Cost after iteration 481: 0.234839
# Cost after iteration 482: 0.234306
# Cost after iteration 483: 0.233777
# Cost after iteration 484: 0.233252
# Cost after iteration 485: 0.232732
# Cost after iteration 486: 0.232216
# Cost after iteration 487: 0.231705
# Cost after iteration 488: 0.231198
# Cost after iteration 489: 0.230695
# Cost after iteration 490: 0.230197
# Cost after iteration 491: 0.229703
# Cost after iteration 492: 0.229213
# Cost after iteration 493: 0.228727
# Cost after iteration 494: 0.228246
# Cost after iteration 495: 0.227769
# Cost after iteration 496: 0.227296
# Cost after iteration 497: 0.226827
# Cost after iteration 498: 0.226363
# Cost after iteration 499: 0.225903
# Cost after iteration 500: 0.225446
# Cost after iteration 501: 0.224995
# Cost after iteration 502: 0.224547
# Cost after iteration 503: 0.224103
# Cost after iteration 504: 0.223664
# Cost after iteration 505: 0.223228
# Cost after iteration 506: 0.222797
# Cost after iteration 507: 0.222370
# Cost after iteration 508: 0.221947
# Cost after iteration 509: 0.221528
# Cost after iteration 510: 0.221113
# Cost after iteration 511: 0.220702
# Cost after iteration 512: 0.220295
# Cost after iteration 513: 0.219892
# Cost after iteration 514: 0.219493
# Cost after iteration 515: 0.219098
# Cost after iteration 516: 0.218707
# Cost after iteration 517: 0.218320
# Cost after iteration 518: 0.217937
# Cost after iteration 519: 0.217557
# Cost after iteration 520: 0.217182
# Cost after iteration 521: 0.216810
# Cost after iteration 522: 0.216442
# Cost after iteration 523: 0.216078
# Cost after iteration 524: 0.215718
# Cost after iteration 525: 0.215361
# Cost after iteration 526: 0.215008
# Cost after iteration 527: 0.214659
# Cost after iteration 528: 0.214313
# Cost after iteration 529: 0.213971
# Cost after iteration 530: 0.213632
# Cost after iteration 531: 0.213297
# Cost after iteration 532: 0.212966
# Cost after iteration 533: 0.212638
# Cost after iteration 534: 0.212314
# Cost after iteration 535: 0.211993
# Cost after iteration 536: 0.211675
# Cost after iteration 537: 0.211361
# Cost after iteration 538: 0.211050
# Cost after iteration 539: 0.210743
# Cost after iteration 540: 0.210439
# Cost after iteration 541: 0.210138
# Cost after iteration 542: 0.209840
# Cost after iteration 543: 0.209546
# Cost after iteration 544: 0.209255
# Cost after iteration 545: 0.208969
# Cost after iteration 546: 0.208693
# Cost after iteration 547: 0.208450
# Cost after iteration 548: 0.208336
# Cost after iteration 549: 0.208772
# Cost after iteration 550: 0.211607
# Cost after iteration 551: 0.225490
# Cost after iteration 552: 0.295532
# Cost after iteration 553: 0.623211
# Cost after iteration 554: 0.683399
# Cost after iteration 555: 1.280983
# Cost after iteration 556: 0.408694
# Cost after iteration 557: 0.361480
# Cost after iteration 558: 0.238692
# Cost after iteration 559: 0.233218
# Cost after iteration 560: 0.229147
# Cost after iteration 561: 0.226915
# Cost after iteration 562: 0.225105
# Cost after iteration 563: 0.223631
# Cost after iteration 564: 0.222344
# Cost after iteration 565: 0.221204
# Cost after iteration 566: 0.220176
# Cost after iteration 567: 0.219239
# Cost after iteration 568: 0.218379
# Cost after iteration 569: 0.217584
# Cost after iteration 570: 0.216845
# Cost after iteration 571: 0.216153
# Cost after iteration 572: 0.215503
# Cost after iteration 573: 0.214889
# Cost after iteration 574: 0.214306
# Cost after iteration 575: 0.213751
# Cost after iteration 576: 0.213220
# Cost after iteration 577: 0.212710
# Cost after iteration 578: 0.212219
# Cost after iteration 579: 0.211745
# Cost after iteration 580: 0.211287
# Cost after iteration 581: 0.210841
# Cost after iteration 582: 0.210408
# Cost after iteration 583: 0.209987
# Cost after iteration 584: 0.209575
# Cost after iteration 585: 0.209173
# Cost after iteration 586: 0.208780
# Cost after iteration 587: 0.208395
# Cost after iteration 588: 0.208017
# Cost after iteration 589: 0.207647
# Cost after iteration 590: 0.207284
# Cost after iteration 591: 0.206928
# Cost after iteration 592: 0.206578
# Cost after iteration 593: 0.206235
# Cost after iteration 594: 0.205897
# Cost after iteration 595: 0.205565
# Cost after iteration 596: 0.205240
# Cost after iteration 597: 0.204920
# Cost after iteration 598: 0.204605
# Cost after iteration 599: 0.204297
# Cost after iteration 600: 0.203995
# Cost after iteration 601: 0.203700
# Cost after iteration 602: 0.203412
# Cost after iteration 603: 0.203133
# Cost after iteration 604: 0.202864
# Cost after iteration 605: 0.202612
# Cost after iteration 606: 0.202383
# Cost after iteration 607: 0.202194
# Cost after iteration 608: 0.202068
# Cost after iteration 609: 0.202072
# Cost after iteration 610: 0.202285
# Cost after iteration 611: 0.202993
# Cost after iteration 612: 0.204513
# Cost after iteration 613: 0.208223
# Cost after iteration 614: 0.215616
# Cost after iteration 615: 0.234908
# Cost after iteration 616: 0.276260
# Cost after iteration 617: 0.412875
# Cost after iteration 618: 0.633478
# Cost after iteration 619: 1.500695
# Cost after iteration 620: 0.361894
# Cost after iteration 621: 0.247717
# Cost after iteration 622: 0.226986
# Cost after iteration 623: 0.222849
# Cost after iteration 624: 0.220596
# Cost after iteration 625: 0.218943
# Cost after iteration 626: 0.217545
# Cost after iteration 627: 0.216303
# Cost after iteration 628: 0.215180
# Cost after iteration 629: 0.214156
# Cost after iteration 630: 0.213214
# Cost after iteration 631: 0.212344
# Cost after iteration 632: 0.211537
# Cost after iteration 633: 0.210786
# Cost after iteration 634: 0.210083
# Cost after iteration 635: 0.209424
# Cost after iteration 636: 0.208803
# Cost after iteration 637: 0.208216
# Cost after iteration 638: 0.207660
# Cost after iteration 639: 0.207132
# Cost after iteration 640: 0.206628
# Cost after iteration 641: 0.206147
# Cost after iteration 642: 0.205685
# Cost after iteration 643: 0.205242
# Cost after iteration 644: 0.204815
# Cost after iteration 645: 0.204403
# Cost after iteration 646: 0.204006
# Cost after iteration 647: 0.203621
# Cost after iteration 648: 0.203247
# Cost after iteration 649: 0.202885
# Cost after iteration 650: 0.202533
# Cost after iteration 651: 0.202191
# Cost after iteration 652: 0.201857
# Cost after iteration 653: 0.201532
# Cost after iteration 654: 0.201215
# Cost after iteration 655: 0.200906
# Cost after iteration 656: 0.200604
# Cost after iteration 657: 0.200309
# Cost after iteration 658: 0.200021
# Cost after iteration 659: 0.199740
# Cost after iteration 660: 0.199464
# Cost after iteration 661: 0.199195
# Cost after iteration 662: 0.198932
# Cost after iteration 663: 0.198674
# Cost after iteration 664: 0.198422
# Cost after iteration 665: 0.198175
# Cost after iteration 666: 0.197934
# Cost after iteration 667: 0.197697
# Cost after iteration 668: 0.197466
# Cost after iteration 669: 0.197240
# Cost after iteration 670: 0.197019
# Cost after iteration 671: 0.196802
# Cost after iteration 672: 0.196590
# Cost after iteration 673: 0.196382
# Cost after iteration 674: 0.196179
# Cost after iteration 675: 0.195980
# Cost after iteration 676: 0.195786
# Cost after iteration 677: 0.195595
# Cost after iteration 678: 0.195409
# Cost after iteration 679: 0.195227
# Cost after iteration 680: 0.195050
# Cost after iteration 681: 0.194877
# Cost after iteration 682: 0.194711
# Cost after iteration 683: 0.194553
# Cost after iteration 684: 0.194409
# Cost after iteration 685: 0.194291
# Cost after iteration 686: 0.194229
# Cost after iteration 687: 0.194284
# Cost after iteration 688: 0.194618
# Cost after iteration 689: 0.195580
# Cost after iteration 690: 0.198182
# Cost after iteration 691: 0.204645
# Cost after iteration 692: 0.223149
# Cost after iteration 693: 0.274981
# Cost after iteration 694: 0.456496
# Cost after iteration 695: 0.672006
# Cost after iteration 696: 1.421963
# Cost after iteration 697: 0.290212
# Cost after iteration 698: 0.228284
# Cost after iteration 699: 0.216011
# Cost after iteration 700: 0.213519
# Cost after iteration 701: 0.211869
# Cost after iteration 702: 0.210600
# Cost after iteration 703: 0.209486
# Cost after iteration 704: 0.208494
# Cost after iteration 705: 0.207588
# Cost after iteration 706: 0.206756
# Cost after iteration 707: 0.205985
# Cost after iteration 708: 0.205268
# Cost after iteration 709: 0.204598
# Cost after iteration 710: 0.203969
# Cost after iteration 711: 0.203378
# Cost after iteration 712: 0.202820
# Cost after iteration 713: 0.202293
# Cost after iteration 714: 0.201793
# Cost after iteration 715: 0.201318
# Cost after iteration 716: 0.200866
# Cost after iteration 717: 0.200435
# Cost after iteration 718: 0.200023
# Cost after iteration 719: 0.199629
# Cost after iteration 720: 0.199250
# Cost after iteration 721: 0.198887
# Cost after iteration 722: 0.198538
# Cost after iteration 723: 0.198201
# Cost after iteration 724: 0.197877
# Cost after iteration 725: 0.197564
# Cost after iteration 726: 0.197262
# Cost after iteration 727: 0.196970
# Cost after iteration 728: 0.196687
# Cost after iteration 729: 0.196413
# Cost after iteration 730: 0.196148
# Cost after iteration 731: 0.195890
# Cost after iteration 732: 0.195641
# Cost after iteration 733: 0.195399
# Cost after iteration 734: 0.195164
# Cost after iteration 735: 0.194937
# Cost after iteration 736: 0.194716
# Cost after iteration 737: 0.194503
# Cost after iteration 738: 0.194297
# Cost after iteration 739: 0.194099
# Cost after iteration 740: 0.193911
# Cost after iteration 741: 0.193733
# Cost after iteration 742: 0.193570
# Cost after iteration 743: 0.193424
# Cost after iteration 744: 0.193310
# Cost after iteration 745: 0.193232
# Cost after iteration 746: 0.193236
# Cost after iteration 747: 0.193324
# Cost after iteration 748: 0.193661
# Cost after iteration 749: 0.194217
# Cost after iteration 750: 0.195634
# Cost after iteration 751: 0.197626
# Cost after iteration 752: 0.203009
# Cost after iteration 753: 0.209464
# Cost after iteration 754: 0.229708
# Cost after iteration 755: 0.241475
# Cost after iteration 756: 0.301901
# Cost after iteration 757: 0.289339
# Cost after iteration 758: 0.394191
# Cost after iteration 759: 0.348118
# Cost after iteration 760: 0.513342
# Cost after iteration 761: 0.483222
# Cost after iteration 762: 0.519289
# Cost after iteration 763: 0.304810
# Cost after iteration 764: 0.260667
# Cost after iteration 765: 0.224411
# Cost after iteration 766: 0.210027
# Cost after iteration 767: 0.204945
# Cost after iteration 768: 0.202962
# Cost after iteration 769: 0.201817
# Cost after iteration 770: 0.201116
# Cost after iteration 771: 0.200559
# Cost after iteration 772: 0.200097
# Cost after iteration 773: 0.199680
# Cost after iteration 774: 0.199294
# Cost after iteration 775: 0.198928
# Cost after iteration 776: 0.198579
# Cost after iteration 777: 0.198243
# Cost after iteration 778: 0.197919
# Cost after iteration 779: 0.197605
# Cost after iteration 780: 0.197300
# Cost after iteration 781: 0.197005
# Cost after iteration 782: 0.196718
# Cost after iteration 783: 0.196440
# Cost after iteration 784: 0.196169
# Cost after iteration 785: 0.195905
# Cost after iteration 786: 0.195649
# Cost after iteration 787: 0.195399
# Cost after iteration 788: 0.195156
# Cost after iteration 789: 0.194920
# Cost after iteration 790: 0.194689
# Cost after iteration 791: 0.194465
# Cost after iteration 792: 0.194246
# Cost after iteration 793: 0.194033
# Cost after iteration 794: 0.193825
# Cost after iteration 795: 0.193622
# Cost after iteration 796: 0.193425
# Cost after iteration 797: 0.193232
# Cost after iteration 798: 0.193045
# Cost after iteration 799: 0.192862
# Cost after iteration 800: 0.192683
# Cost after iteration 801: 0.192509
# Cost after iteration 802: 0.192340
# Cost after iteration 803: 0.192174
# Cost after iteration 804: 0.192013
# Cost after iteration 805: 0.191856
# Cost after iteration 806: 0.191703
# Cost after iteration 807: 0.191553
# Cost after iteration 808: 0.191407
# Cost after iteration 809: 0.191265
# Cost after iteration 810: 0.191126
# Cost after iteration 811: 0.190991
# Cost after iteration 812: 0.190859
# Cost after iteration 813: 0.190730
# Cost after iteration 814: 0.190605
# Cost after iteration 815: 0.190482
# Cost after iteration 816: 0.190363
# Cost after iteration 817: 0.190246
# Cost after iteration 818: 0.190133
# Cost after iteration 819: 0.190023
# Cost after iteration 820: 0.189915
# Cost after iteration 821: 0.189811
# Cost after iteration 822: 0.189711
# Cost after iteration 823: 0.189615
# Cost after iteration 824: 0.189526
# Cost after iteration 825: 0.189445
# Cost after iteration 826: 0.189377
# Cost after iteration 827: 0.189332
# Cost after iteration 828: 0.189329
# Cost after iteration 829: 0.189393
# Cost after iteration 830: 0.189602
# Cost after iteration 831: 0.190042
# Cost after iteration 832: 0.191037
# Cost after iteration 833: 0.192884
# Cost after iteration 834: 0.197140
# Cost after iteration 835: 0.204868
# Cost after iteration 836: 0.225329
# Cost after iteration 837: 0.264570
# Cost after iteration 838: 0.400786
# Cost after iteration 839: 0.569197
# Cost after iteration 840: 1.316850
# Cost after iteration 841: 0.238391
# Cost after iteration 842: 0.225448
# Cost after iteration 843: 0.207191
# Cost after iteration 844: 0.204336
# Cost after iteration 845: 0.202538
# Cost after iteration 846: 0.201462
# Cost after iteration 847: 0.200619
# Cost after iteration 848: 0.199910
# Cost after iteration 849: 0.199276
# Cost after iteration 850: 0.198694
# Cost after iteration 851: 0.198154
# Cost after iteration 852: 0.197648
# Cost after iteration 853: 0.197173
# Cost after iteration 854: 0.196725
# Cost after iteration 855: 0.196303
# Cost after iteration 856: 0.195904
# Cost after iteration 857: 0.195526
# Cost after iteration 858: 0.195168
# Cost after iteration 859: 0.194829
# Cost after iteration 860: 0.194506
# Cost after iteration 861: 0.194199
# Cost after iteration 862: 0.193907
# Cost after iteration 863: 0.193629
# Cost after iteration 864: 0.193363
# Cost after iteration 865: 0.193110
# Cost after iteration 866: 0.192868
# Cost after iteration 867: 0.192636
# Cost after iteration 868: 0.192414
# Cost after iteration 869: 0.192201
# Cost after iteration 870: 0.191997
# Cost after iteration 871: 0.191801
# Cost after iteration 872: 0.191613
# Cost after iteration 873: 0.191432
# Cost after iteration 874: 0.191258
# Cost after iteration 875: 0.191090
# Cost after iteration 876: 0.190928
# Cost after iteration 877: 0.190773
# Cost after iteration 878: 0.190623
# Cost after iteration 879: 0.190477
# Cost after iteration 880: 0.190337
# Cost after iteration 881: 0.190202
# Cost after iteration 882: 0.190071
# Cost after iteration 883: 0.189944
# Cost after iteration 884: 0.189822
# Cost after iteration 885: 0.189703
# Cost after iteration 886: 0.189588
# Cost after iteration 887: 0.189476
# Cost after iteration 888: 0.189368
# Cost after iteration 889: 0.189263
# Cost after iteration 890: 0.189161
# Cost after iteration 891: 0.189062
# Cost after iteration 892: 0.188966
# Cost after iteration 893: 0.188873
# Cost after iteration 894: 0.188782
# Cost after iteration 895: 0.188693
# Cost after iteration 896: 0.188607
# Cost after iteration 897: 0.188523
# Cost after iteration 898: 0.188442
# Cost after iteration 899: 0.188362
# Cost after iteration 900: 0.188285
# Cost after iteration 901: 0.188209
# Cost after iteration 902: 0.188136
# Cost after iteration 903: 0.188064
# Cost after iteration 904: 0.187994
# Cost after iteration 905: 0.187926
# Cost after iteration 906: 0.187861
# Cost after iteration 907: 0.187798
# Cost after iteration 908: 0.187739
# Cost after iteration 909: 0.187684
# Cost after iteration 910: 0.187639
# Cost after iteration 911: 0.187608
# Cost after iteration 912: 0.187604
# Cost after iteration 913: 0.187652
# Cost after iteration 914: 0.187803
# Cost after iteration 915: 0.188144
# Cost after iteration 916: 0.188912
# Cost after iteration 917: 0.190436
# Cost after iteration 918: 0.193904
# Cost after iteration 919: 0.200679
# Cost after iteration 920: 0.218408
# Cost after iteration 921: 0.256198
# Cost after iteration 922: 0.388574
# Cost after iteration 923: 0.550384
# Cost after iteration 924: 1.102707
# Cost after iteration 925: 0.359403
# Cost after iteration 926: 0.432278
# Cost after iteration 927: 0.210222
# Cost after iteration 928: 0.204264
# Cost after iteration 929: 0.201447
# Cost after iteration 930: 0.200186
# Cost after iteration 931: 0.199350
# Cost after iteration 932: 0.198687
# Cost after iteration 933: 0.198101
# Cost after iteration 934: 0.197562
# Cost after iteration 935: 0.197060
# Cost after iteration 936: 0.196589
# Cost after iteration 937: 0.196145
# Cost after iteration 938: 0.195726
# Cost after iteration 939: 0.195330
# Cost after iteration 940: 0.194956
# Cost after iteration 941: 0.194602
# Cost after iteration 942: 0.194266
# Cost after iteration 943: 0.193948
# Cost after iteration 944: 0.193645
# Cost after iteration 945: 0.193358
# Cost after iteration 946: 0.193085
# Cost after iteration 947: 0.192825
# Cost after iteration 948: 0.192577
# Cost after iteration 949: 0.192341
# Cost after iteration 950: 0.192115
# Cost after iteration 951: 0.191900
# Cost after iteration 952: 0.191694
# Cost after iteration 953: 0.191497
# Cost after iteration 954: 0.191309
# Cost after iteration 955: 0.191128
# Cost after iteration 956: 0.190954
# Cost after iteration 957: 0.190788
# Cost after iteration 958: 0.190628
# Cost after iteration 959: 0.190475
# Cost after iteration 960: 0.190327
# Cost after iteration 961: 0.190185
# Cost after iteration 962: 0.190048
# Cost after iteration 963: 0.189916
# Cost after iteration 964: 0.189789
# Cost after iteration 965: 0.189666
# Cost after iteration 966: 0.189548
# Cost after iteration 967: 0.189433
# Cost after iteration 968: 0.189323
# Cost after iteration 969: 0.189216
# Cost after iteration 970: 0.189112
# Cost after iteration 971: 0.189012
# Cost after iteration 972: 0.188915
# Cost after iteration 973: 0.188820
# Cost after iteration 974: 0.188729
# Cost after iteration 975: 0.188640
# Cost after iteration 976: 0.188554
# Cost after iteration 977: 0.188471
# Cost after iteration 978: 0.188389
# Cost after iteration 979: 0.188310
# Cost after iteration 980: 0.188234
# Cost after iteration 981: 0.188159
# Cost after iteration 982: 0.188086
# Cost after iteration 983: 0.188015
# Cost after iteration 984: 0.187946
# Cost after iteration 985: 0.187879
# Cost after iteration 986: 0.187813
# Cost after iteration 987: 0.187749
# Cost after iteration 988: 0.187686
# Cost after iteration 989: 0.187625
# Cost after iteration 990: 0.187565
# Cost after iteration 991: 0.187507
# Cost after iteration 992: 0.187450
# Cost after iteration 993: 0.187394
# Cost after iteration 994: 0.187340
# Cost after iteration 995: 0.187286
# Cost after iteration 996: 0.187234
# Cost after iteration 997: 0.187183
# Cost after iteration 998: 0.187133
# Cost after iteration 999: 0.187084
# Cost after iteration 1000: 0.187036
# Cost after iteration 1001: 0.186989
# Cost after iteration 1002: 0.186943
# Cost after iteration 1003: 0.186898
# Cost after iteration 1004: 0.186854
# Cost after iteration 1005: 0.186812
# Cost after iteration 1006: 0.186772
# Cost after iteration 1007: 0.186736
# Cost after iteration 1008: 0.186707
# Cost after iteration 1009: 0.186690
# Cost after iteration 1010: 0.186696
# Cost after iteration 1011: 0.186748
# Cost after iteration 1012: 0.186894
# Cost after iteration 1013: 0.187220
# Cost after iteration 1014: 0.187949
# Cost after iteration 1015: 0.189422
# Cost after iteration 1016: 0.192783
# Cost after iteration 1017: 0.199506
# Cost after iteration 1018: 0.217411
# Cost after iteration 1019: 0.256753
# Cost after iteration 1020: 0.397087
# Cost after iteration 1021: 0.525811
# Cost after iteration 1022: 0.804121
# Cost after iteration 1023: 0.372458
# Cost after iteration 1024: 0.539576
# Cost after iteration 1025: 0.238200
# Cost after iteration 1026: 0.225530
# Cost after iteration 1027: 0.204498
# Cost after iteration 1028: 0.200426
# Cost after iteration 1029: 0.197818
# Cost after iteration 1030: 0.196618
# Cost after iteration 1031: 0.195830
# Cost after iteration 1032: 0.195276
# Cost after iteration 1033: 0.194819
# Cost after iteration 1034: 0.194419
# Cost after iteration 1035: 0.194054
# Cost after iteration 1036: 0.193713
# Cost after iteration 1037: 0.193392
# Cost after iteration 1038: 0.193088
# Cost after iteration 1039: 0.192800
# Cost after iteration 1040: 0.192527
# Cost after iteration 1041: 0.192267
# Cost after iteration 1042: 0.192019
# Cost after iteration 1043: 0.191783
# Cost after iteration 1044: 0.191558
# Cost after iteration 1045: 0.191343
# Cost after iteration 1046: 0.191138
# Cost after iteration 1047: 0.190942
# Cost after iteration 1048: 0.190754
# Cost after iteration 1049: 0.190575
# Cost after iteration 1050: 0.190403
# Cost after iteration 1051: 0.190239
# Cost after iteration 1052: 0.190081
# Cost after iteration 1053: 0.189930
# Cost after iteration 1054: 0.189785
# Cost after iteration 1055: 0.189645
# Cost after iteration 1056: 0.189511
# Cost after iteration 1057: 0.189383
# Cost after iteration 1058: 0.189259
# Cost after iteration 1059: 0.189140
# Cost after iteration 1060: 0.189025
# Cost after iteration 1061: 0.188914
# Cost after iteration 1062: 0.188808
# Cost after iteration 1063: 0.188705
# Cost after iteration 1064: 0.188606
# Cost after iteration 1065: 0.188510
# Cost after iteration 1066: 0.188417
# Cost after iteration 1067: 0.188328
# Cost after iteration 1068: 0.188241
# Cost after iteration 1069: 0.188157
# Cost after iteration 1070: 0.188076
# Cost after iteration 1071: 0.187998
# Cost after iteration 1072: 0.187922
# Cost after iteration 1073: 0.187848
# Cost after iteration 1074: 0.187776
# Cost after iteration 1075: 0.187707
# Cost after iteration 1076: 0.187640
# Cost after iteration 1077: 0.187574
# Cost after iteration 1078: 0.187511
# Cost after iteration 1079: 0.187449
# Cost after iteration 1080: 0.187389
# Cost after iteration 1081: 0.187330
# Cost after iteration 1082: 0.187273
# Cost after iteration 1083: 0.187218
# Cost after iteration 1084: 0.187164
# Cost after iteration 1085: 0.187111
# Cost after iteration 1086: 0.187060
# Cost after iteration 1087: 0.187010
# Cost after iteration 1088: 0.186961
# Cost after iteration 1089: 0.186913
# Cost after iteration 1090: 0.186867
# Cost after iteration 1091: 0.186822
# Cost after iteration 1092: 0.186777
# Cost after iteration 1093: 0.186734
# Cost after iteration 1094: 0.186692
# Cost after iteration 1095: 0.186650
# Cost after iteration 1096: 0.186610
# Cost after iteration 1097: 0.186572
# Cost after iteration 1098: 0.186534
# Cost after iteration 1099: 0.186499
# Cost after iteration 1100: 0.186467
# Cost after iteration 1101: 0.186440
# Cost after iteration 1102: 0.186421
# Cost after iteration 1103: 0.186414
# Cost after iteration 1104: 0.186432
# Cost after iteration 1105: 0.186489
# Cost after iteration 1106: 0.186627
# Cost after iteration 1107: 0.186895
# Cost after iteration 1108: 0.187451
# Cost after iteration 1109: 0.188442
# Cost after iteration 1110: 0.190559
# Cost after iteration 1111: 0.194185
# Cost after iteration 1112: 0.202815
# Cost after iteration 1113: 0.217316
# Cost after iteration 1114: 0.260122
# Cost after iteration 1115: 0.329046
# Cost after iteration 1116: 0.606461
# Cost after iteration 1117: 0.637574
# Cost after iteration 1118: 1.368826
# Cost after iteration 1119: 0.227450
# Cost after iteration 1120: 0.207933
# Cost after iteration 1121: 0.205158
# Cost after iteration 1122: 0.203721
# Cost after iteration 1123: 0.202669
# Cost after iteration 1124: 0.201758
# Cost after iteration 1125: 0.200929
# Cost after iteration 1126: 0.200163
# Cost after iteration 1127: 0.199449
# Cost after iteration 1128: 0.198784
# Cost after iteration 1129: 0.198161
# Cost after iteration 1130: 0.197578
# Cost after iteration 1131: 0.197031
# Cost after iteration 1132: 0.196518
# Cost after iteration 1133: 0.196035
# Cost after iteration 1134: 0.195580
# Cost after iteration 1135: 0.195152
# Cost after iteration 1136: 0.194748
# Cost after iteration 1137: 0.194366
# Cost after iteration 1138: 0.194006
# Cost after iteration 1139: 0.193665
# Cost after iteration 1140: 0.193343
# Cost after iteration 1141: 0.193037
# Cost after iteration 1142: 0.192748
# Cost after iteration 1143: 0.192474
# Cost after iteration 1144: 0.192213
# Cost after iteration 1145: 0.191966
# Cost after iteration 1146: 0.191731
# Cost after iteration 1147: 0.191507
# Cost after iteration 1148: 0.191294
# Cost after iteration 1149: 0.191092
# Cost after iteration 1150: 0.190898
# Cost after iteration 1151: 0.190714
# Cost after iteration 1152: 0.190539
# Cost after iteration 1153: 0.190371
# Cost after iteration 1154: 0.190211
# Cost after iteration 1155: 0.190057
# Cost after iteration 1156: 0.189911
# Cost after iteration 1157: 0.189770
# Cost after iteration 1158: 0.189636
# Cost after iteration 1159: 0.189507
# Cost after iteration 1160: 0.189383
# Cost after iteration 1161: 0.189265
# Cost after iteration 1162: 0.189151
# Cost after iteration 1163: 0.189041
# Cost after iteration 1164: 0.188936
# Cost after iteration 1165: 0.188835
# Cost after iteration 1166: 0.188737
# Cost after iteration 1167: 0.188644
# Cost after iteration 1168: 0.188553
# Cost after iteration 1169: 0.188466
# Cost after iteration 1170: 0.188381
# Cost after iteration 1171: 0.188300
# Cost after iteration 1172: 0.188222
# Cost after iteration 1173: 0.188146
# Cost after iteration 1174: 0.188072
# Cost after iteration 1175: 0.188001
# Cost after iteration 1176: 0.187932
# Cost after iteration 1177: 0.187865
# Cost after iteration 1178: 0.187801
# Cost after iteration 1179: 0.187738
# Cost after iteration 1180: 0.187677
# Cost after iteration 1181: 0.187618
# Cost after iteration 1182: 0.187561
# Cost after iteration 1183: 0.187505
# Cost after iteration 1184: 0.187451
# Cost after iteration 1185: 0.187398
# Cost after iteration 1186: 0.187347
# Cost after iteration 1187: 0.187297
# Cost after iteration 1188: 0.187248
# Cost after iteration 1189: 0.187201
# Cost after iteration 1190: 0.187154
# Cost after iteration 1191: 0.187109
# Cost after iteration 1192: 0.187065
# Cost after iteration 1193: 0.187022
# Cost after iteration 1194: 0.186980
# Cost after iteration 1195: 0.186939
# Cost after iteration 1196: 0.186899
# Cost after iteration 1197: 0.186860
# Cost after iteration 1198: 0.186822
# Cost after iteration 1199: 0.186784
# Cost after iteration 1200: 0.186747
# Cost after iteration 1201: 0.186711
# Cost after iteration 1202: 0.186676
# Cost after iteration 1203: 0.186641
# Cost after iteration 1204: 0.186608
# Cost after iteration 1205: 0.186574
# Cost after iteration 1206: 0.186542
# Cost after iteration 1207: 0.186510
# Cost after iteration 1208: 0.186478
# Cost after iteration 1209: 0.186447
# Cost after iteration 1210: 0.186417
# Cost after iteration 1211: 0.186387
# Cost after iteration 1212: 0.186358
# Cost after iteration 1213: 0.186329
# Cost after iteration 1214: 0.186301
# Cost after iteration 1215: 0.186273
# Cost after iteration 1216: 0.186245
# Cost after iteration 1217: 0.186218
# Cost after iteration 1218: 0.186192
# Cost after iteration 1219: 0.186165
# Cost after iteration 1220: 0.186140
# Cost after iteration 1221: 0.186114
# Cost after iteration 1222: 0.186089
# Cost after iteration 1223: 0.186064
# Cost after iteration 1224: 0.186040
# Cost after iteration 1225: 0.186016
# Cost after iteration 1226: 0.185992
# Cost after iteration 1227: 0.185968
# Cost after iteration 1228: 0.185945
# Cost after iteration 1229: 0.185922
# Cost after iteration 1230: 0.185900
# Cost after iteration 1231: 0.185878
# Cost after iteration 1232: 0.185856
# Cost after iteration 1233: 0.185834
# Cost after iteration 1234: 0.185812
# Cost after iteration 1235: 0.185791
# Cost after iteration 1236: 0.185770
# Cost after iteration 1237: 0.185749
# Cost after iteration 1238: 0.185729
# Cost after iteration 1239: 0.185709
# Cost after iteration 1240: 0.185690
# Cost after iteration 1241: 0.185673
# Cost after iteration 1242: 0.185658
# Cost after iteration 1243: 0.185650
# Cost after iteration 1244: 0.185656
# Cost after iteration 1245: 0.185692
# Cost after iteration 1246: 0.185790
# Cost after iteration 1247: 0.186045
# Cost after iteration 1248: 0.186599
# Cost after iteration 1249: 0.188021
# Cost after iteration 1250: 0.190900
# Cost after iteration 1251: 0.199320
# Cost after iteration 1252: 0.215104
# Cost after iteration 1253: 0.269091
# Cost after iteration 1254: 0.315840
# Cost after iteration 1255: 0.581248
# Cost after iteration 1256: 0.480956
# Cost after iteration 1257: 0.951382
# Cost after iteration 1258: 0.295935
# Cost after iteration 1259: 0.286831
# Cost after iteration 1260: 0.235736
# Cost after iteration 1261: 0.219329
# Cost after iteration 1262: 0.206965
# Cost after iteration 1263: 0.200651
# Cost after iteration 1264: 0.197457
# Cost after iteration 1265: 0.195836
# Cost after iteration 1266: 0.194926
# Cost after iteration 1267: 0.194326
# Cost after iteration 1268: 0.193859
# Cost after iteration 1269: 0.193461
# Cost after iteration 1270: 0.193103
# Cost after iteration 1271: 0.192773
# Cost after iteration 1272: 0.192464
# Cost after iteration 1273: 0.192175
# Cost after iteration 1274: 0.191902
# Cost after iteration 1275: 0.191645
# Cost after iteration 1276: 0.191402
# Cost after iteration 1277: 0.191172
# Cost after iteration 1278: 0.190954
# Cost after iteration 1279: 0.190748
# Cost after iteration 1280: 0.190553
# Cost after iteration 1281: 0.190367
# Cost after iteration 1282: 0.190192
# Cost after iteration 1283: 0.190025
# Cost after iteration 1284: 0.189866
# Cost after iteration 1285: 0.189715
# Cost after iteration 1286: 0.189571
# Cost after iteration 1287: 0.189434
# Cost after iteration 1288: 0.189304
# Cost after iteration 1289: 0.189179
# Cost after iteration 1290: 0.189060
# Cost after iteration 1291: 0.188947
# Cost after iteration 1292: 0.188838
# Cost after iteration 1293: 0.188734
# Cost after iteration 1294: 0.188635
# Cost after iteration 1295: 0.188540
# Cost after iteration 1296: 0.188448
# Cost after iteration 1297: 0.188360
# Cost after iteration 1298: 0.188276
# Cost after iteration 1299: 0.188195
# Cost after iteration 1300: 0.188117
# Cost after iteration 1301: 0.188042
# Cost after iteration 1302: 0.187970
# Cost after iteration 1303: 0.187900
# Cost after iteration 1304: 0.187832
# Cost after iteration 1305: 0.187767
# Cost after iteration 1306: 0.187704
# Cost after iteration 1307: 0.187644
# Cost after iteration 1308: 0.187585
# Cost after iteration 1309: 0.187528
# Cost after iteration 1310: 0.187472
# Cost after iteration 1311: 0.187419
# Cost after iteration 1312: 0.187367
# Cost after iteration 1313: 0.187316
# Cost after iteration 1314: 0.187267
# Cost after iteration 1315: 0.187219
# Cost after iteration 1316: 0.187173
# Cost after iteration 1317: 0.187127
# Cost after iteration 1318: 0.187083
# Cost after iteration 1319: 0.187040
# Cost after iteration 1320: 0.186998
# Cost after iteration 1321: 0.186957
# Cost after iteration 1322: 0.186917
# Cost after iteration 1323: 0.186878
# Cost after iteration 1324: 0.186840
# Cost after iteration 1325: 0.186802
# Cost after iteration 1326: 0.186766
# Cost after iteration 1327: 0.186730
# Cost after iteration 1328: 0.186695
# Cost after iteration 1329: 0.186662
# Cost after iteration 1330: 0.186629
# Cost after iteration 1331: 0.186597
# Cost after iteration 1332: 0.186567
# Cost after iteration 1333: 0.186538
# Cost after iteration 1334: 0.186513
# Cost after iteration 1335: 0.186491
# Cost after iteration 1336: 0.186474
# Cost after iteration 1337: 0.186468
# Cost after iteration 1338: 0.186475
# Cost after iteration 1339: 0.186508
# Cost after iteration 1340: 0.186579
# Cost after iteration 1341: 0.186720
# Cost after iteration 1342: 0.186968
# Cost after iteration 1343: 0.187428
# Cost after iteration 1344: 0.188189
# Cost after iteration 1345: 0.189623
# Cost after iteration 1346: 0.191942
# Cost after iteration 1347: 0.196651
# Cost after iteration 1348: 0.204206
# Cost after iteration 1349: 0.223170
# Cost after iteration 1350: 0.255056
# Cost after iteration 1351: 0.365111
# Cost after iteration 1352: 0.435783
# Cost after iteration 1353: 0.585772
# Cost after iteration 1354: 0.361876
# Cost after iteration 1355: 0.456686
# Cost after iteration 1356: 0.301285
# Cost after iteration 1357: 0.313133
# Cost after iteration 1358: 0.224462
# Cost after iteration 1359: 0.217824
# Cost after iteration 1360: 0.203049
# Cost after iteration 1361: 0.199974
# Cost after iteration 1362: 0.196328
# Cost after iteration 1363: 0.194877
# ...
# Cost after iteration 2560: 0.187703
# Cost after iteration 2561: 0.187675
# Cost after iteration 2562: 0.187648
# Cost after iteration 2563: 0.187629
# Cost after iteration 2564: 0.187611
# Cost after iteration 2565: 0.187606
# Cost after iteration 2566: 0.187602
# Cost after iteration 2567: 0.187623
# Cost after iteration 2568: 0.187645
# Cost after iteration 2569: 0.187714
# Cost after iteration 2570: 0.187782
# Cost after iteration 2571: 0.187948
# Cost after iteration 2572: 0.188105
# Cost after iteration 2573: 0.188481
# Cost after iteration 2574: 0.188816
# Cost after iteration 2575: 0.189675
# Cost after iteration 2576: 0.190392
# Cost after iteration 2577: 0.192442
# Cost after iteration 2578: 0.194049
# Cost after iteration 2579: 0.199253
# Cost after iteration 2580: 0.202869
# Cost after iteration 2581: 0.216253
# Cost after iteration 2582: 0.220265
# Cost after iteration 2583: 0.248967
# Cost after iteration 2584: 0.235168
# Cost after iteration 2585: 0.269165
# Cost after iteration 2586: 0.231702
# Cost after iteration 2587: 0.248063
# Cost after iteration 2588: 0.217682
# Cost after iteration 2589: 0.221936
# Cost after iteration 2590: 0.209869
# Cost after iteration 2591: 0.211347
# Cost after iteration 2592: 0.205802
# Cost after iteration 2593: 0.206624
# Cost after iteration 2594: 0.203767
# Cost after iteration 2595: 0.204632
# Cost after iteration 2596: 0.203020
# Cost after iteration 2597: 0.204078
# Cost after iteration 2598: 0.202882
# Cost after iteration 2599: 0.203976
# Cost after iteration 2600: 0.202730
# Cost after iteration 2601: 0.203610
# Cost after iteration 2602: 0.202121
# Cost after iteration 2603: 0.202575
# Cost after iteration 2604: 0.200855
# Cost after iteration 2605: 0.200805
# Cost after iteration 2606: 0.199005
# Cost after iteration 2607: 0.198546
# Cost after iteration 2608: 0.196871
# Cost after iteration 2609: 0.196212
# Cost after iteration 2610: 0.194814
# Cost after iteration 2611: 0.194153
# Cost after iteration 2612: 0.193081
# Cost after iteration 2613: 0.192528
# Cost after iteration 2614: 0.191749
# Cost after iteration 2615: 0.191332
# Cost after iteration 2616: 0.190781
# Cost after iteration 2617: 0.190485
# Cost after iteration 2618: 0.190098
# Cost after iteration 2619: 0.189896
# Cost after iteration 2620: 0.189622
# Cost after iteration 2621: 0.189493
# Cost after iteration 2622: 0.189297
# Cost after iteration 2623: 0.189225
# Cost after iteration 2624: 0.189085
# Cost after iteration 2625: 0.189062
# Cost after iteration 2626: 0.188965
# Cost after iteration 2627: 0.188990
# Cost after iteration 2628: 0.188930
# Cost after iteration 2629: 0.189009
# Cost after iteration 2630: 0.188985
# Cost after iteration 2631: 0.189136
# Cost after iteration 2632: 0.189153
# Cost after iteration 2633: 0.189407
# Cost after iteration 2634: 0.189479
# Cost after iteration 2635: 0.189895
# Cost after iteration 2636: 0.190045
# Cost after iteration 2637: 0.190734
# Cost after iteration 2638: 0.191008
# Cost after iteration 2639: 0.192181
# Cost after iteration 2640: 0.192663
# Cost after iteration 2641: 0.194744
# Cost after iteration 2642: 0.195592
# Cost after iteration 2643: 0.199435
# Cost after iteration 2644: 0.200847
# Cost after iteration 2645: 0.208047
# Cost after iteration 2646: 0.209584
# Cost after iteration 2647: 0.222108
# Cost after iteration 2648: 0.220151
# Cost after iteration 2649: 0.237418
# Cost after iteration 2650: 0.226808
# Cost after iteration 2651: 0.243340
# Cost after iteration 2652: 0.228426
# Cost after iteration 2653: 0.241311
# Cost after iteration 2654: 0.230301
# Cost after iteration 2655: 0.242895
# Cost after iteration 2656: 0.237133
# Cost after iteration 2657: 0.255158
# Cost after iteration 2658: 0.251177
# Cost after iteration 2659: 0.279467
# Cost after iteration 2660: 0.265330
# Cost after iteration 2661: 0.293230
# Cost after iteration 2662: 0.258548
# Cost after iteration 2663: 0.264221
# Cost after iteration 2664: 0.231955
# Cost after iteration 2665: 0.221684
# Cost after iteration 2666: 0.206453
# Cost after iteration 2667: 0.199863
# Cost after iteration 2668: 0.194952
# Cost after iteration 2669: 0.193058
# Cost after iteration 2670: 0.191626
# Cost after iteration 2671: 0.191004
# Cost after iteration 2672: 0.190460
# Cost after iteration 2673: 0.190166
# Cost after iteration 2674: 0.189897
# Cost after iteration 2675: 0.189718
# Cost after iteration 2676: 0.189553
# Cost after iteration 2677: 0.189424
# Cost after iteration 2678: 0.189304
# Cost after iteration 2679: 0.189200
# Cost after iteration 2680: 0.189102
# Cost after iteration 2681: 0.189013
# Cost after iteration 2682: 0.188928
# Cost after iteration 2683: 0.188849
# Cost after iteration 2684: 0.188772
# Cost after iteration 2685: 0.188700
# Cost after iteration 2686: 0.188630
# Cost after iteration 2687: 0.188563
# Cost after iteration 2688: 0.188498
# Cost after iteration 2689: 0.188436
# Cost after iteration 2690: 0.188375
# Cost after iteration 2691: 0.188317
# Cost after iteration 2692: 0.188261
# Cost after iteration 2693: 0.188206
# Cost after iteration 2694: 0.188153
# Cost after iteration 2695: 0.188102
# Cost after iteration 2696: 0.188052
# Cost after iteration 2697: 0.188004
# Cost after iteration 2698: 0.187957
# Cost after iteration 2699: 0.187912
# Cost after iteration 2700: 0.187868
# Cost after iteration 2701: 0.187825
# Cost after iteration 2702: 0.187784
# Cost after iteration 2703: 0.187744
# Cost after iteration 2704: 0.187705
# Cost after iteration 2705: 0.187668
# Cost after iteration 2706: 0.187633
# Cost after iteration 2707: 0.187599
# Cost after iteration 2708: 0.187566
# Cost after iteration 2709: 0.187537
# Cost after iteration 2710: 0.187508
# Cost after iteration 2711: 0.187484
# Cost after iteration 2712: 0.187462
# Cost after iteration 2713: 0.187447
# Cost after iteration 2714: 0.187434
# Cost after iteration 2715: 0.187435
# Cost after iteration 2716: 0.187439
# Cost after iteration 2717: 0.187469
# Cost after iteration 2718: 0.187505
# Cost after iteration 2719: 0.187596
# Cost after iteration 2720: 0.187694
# Cost after iteration 2721: 0.187916
# Cost after iteration 2722: 0.188141
# Cost after iteration 2723: 0.188667
# Cost after iteration 2724: 0.189165
# Cost after iteration 2725: 0.190444
# Cost after iteration 2726: 0.191573
# Cost after iteration 2727: 0.194873
# Cost after iteration 2728: 0.197581
# Cost after iteration 2729: 0.206573
# Cost after iteration 2730: 0.212099
# Cost after iteration 2731: 0.235109
# Cost after iteration 2732: 0.232807
# Cost after iteration 2733: 0.272307
# Cost after iteration 2734: 0.240051
# Cost after iteration 2735: 0.269168
# Cost after iteration 2736: 0.226011
# Cost after iteration 2737: 0.234001
# Cost after iteration 2738: 0.214510
# Cost after iteration 2739: 0.217157
# Cost after iteration 2740: 0.210171
# Cost after iteration 2741: 0.212189
# Cost after iteration 2742: 0.209107
# Cost after iteration 2743: 0.211694
# Cost after iteration 2744: 0.210192
# Cost after iteration 2745: 0.213768
# Cost after iteration 2746: 0.212524
# Cost after iteration 2747: 0.216929
# Cost after iteration 2748: 0.214919
# Cost after iteration 2749: 0.219368
# Cost after iteration 2750: 0.215810
# Cost after iteration 2751: 0.218865
# Cost after iteration 2752: 0.213626
# Cost after iteration 2753: 0.213956
# Cost after iteration 2754: 0.208027
# Cost after iteration 2755: 0.205940
# Cost after iteration 2756: 0.200952
# Cost after iteration 2757: 0.198406
# Cost after iteration 2758: 0.195265
# Cost after iteration 2759: 0.193555
# Cost after iteration 2760: 0.191932
# Cost after iteration 2761: 0.191025
# Cost after iteration 2762: 0.190230
# Cost after iteration 2763: 0.189769
# Cost after iteration 2764: 0.189359
# Cost after iteration 2765: 0.189110
# Cost after iteration 2766: 0.188875
# Cost after iteration 2767: 0.188726
# Cost after iteration 2768: 0.188575
# Cost after iteration 2769: 0.188476
# Cost after iteration 2770: 0.188368
# Cost after iteration 2771: 0.188296
# Cost after iteration 2772: 0.188214
# Cost after iteration 2773: 0.188159
# Cost after iteration 2774: 0.188093
# Cost after iteration 2775: 0.188050
# Cost after iteration 2776: 0.187996
# Cost after iteration 2777: 0.187963
# Cost after iteration 2778: 0.187919
# Cost after iteration 2779: 0.187896
# Cost after iteration 2780: 0.187862
# Cost after iteration 2781: 0.187852
# Cost after iteration 2782: 0.187827
# Cost after iteration 2783: 0.187834
# Cost after iteration 2784: 0.187822
# Cost after iteration 2785: 0.187854
# Cost after iteration 2786: 0.187860
# Cost after iteration 2787: 0.187930
# Cost after iteration 2788: 0.187964
# Cost after iteration 2789: 0.188100
# Cost after iteration 2790: 0.188177
# Cost after iteration 2791: 0.188429
# Cost after iteration 2792: 0.188580
# Cost after iteration 2793: 0.189052
# Cost after iteration 2794: 0.189335
# Cost after iteration 2795: 0.190243
# Cost after iteration 2796: 0.190778
# Cost after iteration 2797: 0.192610
# Cost after iteration 2798: 0.193656
# Cost after iteration 2799: 0.197558
# Cost after iteration 2800: 0.199598
# Cost after iteration 2801: 0.208113
# Cost after iteration 2802: 0.210790
# Cost after iteration 2803: 0.227653
# Cost after iteration 2804: 0.223762
# Cost after iteration 2805: 0.247386
# Cost after iteration 2806: 0.228146
# Cost after iteration 2807: 0.246705
# Cost after iteration 2808: 0.223527
# Cost after iteration 2809: 0.233271
# Cost after iteration 2810: 0.219590
# Cost after iteration 2811: 0.226083
# Cost after iteration 2812: 0.219745
# Cost after iteration 2813: 0.226906
# Cost after iteration 2814: 0.224369
# Cost after iteration 2815: 0.235495
# Cost after iteration 2816: 0.234603
# Cost after iteration 2817: 0.253514
# Cost after iteration 2818: 0.249046
# Cost after iteration 2819: 0.274454
# Cost after iteration 2820: 0.255174
# Cost after iteration 2821: 0.270997
# Cost after iteration 2822: 0.240667
# Cost after iteration 2823: 0.236966
# Cost after iteration 2824: 0.216198
# Cost after iteration 2825: 0.207125
# Cost after iteration 2826: 0.198585
# Cost after iteration 2827: 0.194910
# Cost after iteration 2828: 0.192453
# Cost after iteration 2829: 0.191444
# Cost after iteration 2830: 0.190666
# Cost after iteration 2831: 0.190289
# Cost after iteration 2832: 0.189939
# Cost after iteration 2833: 0.189732
# Cost after iteration 2834: 0.189527
# Cost after iteration 2835: 0.189385
# Cost after iteration 2836: 0.189244
# Cost after iteration 2837: 0.189134
# Cost after iteration 2838: 0.189025
# Cost after iteration 2839: 0.188932
# Cost after iteration 2840: 0.188842
# Cost after iteration 2841: 0.188762
# Cost after iteration 2842: 0.188683
# Cost after iteration 2843: 0.188611
# Cost after iteration 2844: 0.188540
# Cost after iteration 2845: 0.188475
# Cost after iteration 2846: 0.188411
# Cost after iteration 2847: 0.188351
# Cost after iteration 2848: 0.188292
# Cost after iteration 2849: 0.188237
# Cost after iteration 2850: 0.188182
# Cost after iteration 2851: 0.188131
# Cost after iteration 2852: 0.188081
# Cost after iteration 2853: 0.188034
# Cost after iteration 2854: 0.187988
# Cost after iteration 2855: 0.187945
# Cost after iteration 2856: 0.187903
# Cost after iteration 2857: 0.187864
# Cost after iteration 2858: 0.187827
# Cost after iteration 2859: 0.187794
# Cost after iteration 2860: 0.187761
# Cost after iteration 2861: 0.187736
# Cost after iteration 2862: 0.187711
# Cost after iteration 2863: 0.187696
# Cost after iteration 2864: 0.187681
# Cost after iteration 2865: 0.187683
# Cost after iteration 2866: 0.187685
# Cost after iteration 2867: 0.187718
# Cost after iteration 2868: 0.187747
# Cost after iteration 2869: 0.187837
# Cost after iteration 2870: 0.187917
# Cost after iteration 2871: 0.188119
# Cost after iteration 2872: 0.188295
# Cost after iteration 2873: 0.188736
# Cost after iteration 2874: 0.189100
# Cost after iteration 2875: 0.190080
# Cost after iteration 2876: 0.190843
# Cost after iteration 2877: 0.193132
# Cost after iteration 2878: 0.194814
# Cost after iteration 2879: 0.200485
# Cost after iteration 2880: 0.204086
# Cost after iteration 2881: 0.218115
# Cost after iteration 2882: 0.220998
# Cost after iteration 2883: 0.249116
# Cost after iteration 2884: 0.233629
# Cost after iteration 2885: 0.264235
# Cost after iteration 2886: 0.228893
# Cost after iteration 2887: 0.243055
# Cost after iteration 2888: 0.216312
# Cost after iteration 2889: 0.220315
# Cost after iteration 2890: 0.209099
# Cost after iteration 2891: 0.210491
# Cost after iteration 2892: 0.205036
# Cost after iteration 2893: 0.205696
# Cost after iteration 2894: 0.202781
# Cost after iteration 2895: 0.203382
# Cost after iteration 2896: 0.201712
# Cost after iteration 2897: 0.202430
# Cost after iteration 2898: 0.201248
# Cost after iteration 2899: 0.201984
# Cost after iteration 2900: 0.200866
# Cost after iteration 2901: 0.201446
# Cost after iteration 2902: 0.200216
# Cost after iteration 2903: 0.200508
# Cost after iteration 2904: 0.199156
# Cost after iteration 2905: 0.199120
# Cost after iteration 2906: 0.197732
# Cost after iteration 2907: 0.197428
# Cost after iteration 2908: 0.196121
# Cost after iteration 2909: 0.195670
# Cost after iteration 2910: 0.194540
# Cost after iteration 2911: 0.194061
# Cost after iteration 2912: 0.193148
# Cost after iteration 2913: 0.192720
# Cost after iteration 2914: 0.192018
# Cost after iteration 2915: 0.191675
# Cost after iteration 2916: 0.191149
# Cost after iteration 2917: 0.190894
# Cost after iteration 2918: 0.190505
# Cost after iteration 2919: 0.190330
# Cost after iteration 2920: 0.190044
# Cost after iteration 2921: 0.189936
# Cost after iteration 2922: 0.189728
# Cost after iteration 2923: 0.189679
# Cost after iteration 2924: 0.189531
# Cost after iteration 2925: 0.189539
# Cost after iteration 2926: 0.189439
# Cost after iteration 2927: 0.189510
# Cost after iteration 2928: 0.189455
# Cost after iteration 2929: 0.189602
# Cost after iteration 2930: 0.189593
# Cost after iteration 2931: 0.189845
# Cost after iteration 2932: 0.189892
# Cost after iteration 2933: 0.190303
# Cost after iteration 2934: 0.190425
# Cost after iteration 2935: 0.191092
# Cost after iteration 2936: 0.191325
# Cost after iteration 2937: 0.192432
# Cost after iteration 2938: 0.192845
# Cost after iteration 2939: 0.194747
# Cost after iteration 2940: 0.195466
# Cost after iteration 2941: 0.198866
# Cost after iteration 2942: 0.200058
# Cost after iteration 2943: 0.206265
# Cost after iteration 2944: 0.207727
# Cost after iteration 2945: 0.218529
# Cost after iteration 2946: 0.217821
# Cost after iteration 2947: 0.233483
# Cost after iteration 2948: 0.225578
# Cost after iteration 2949: 0.241991
# Cost after iteration 2950: 0.228326
# Cost after iteration 2951: 0.241643
# Cost after iteration 2952: 0.229815
# Cost after iteration 2953: 0.241779
# Cost after iteration 2954: 0.234547
# Cost after iteration 2955: 0.249504
# Cost after iteration 2956: 0.244561
# Cost after iteration 2957: 0.266391
# Cost after iteration 2958: 0.256398
# Cost after iteration 2959: 0.280560
# Cost after iteration 2960: 0.255692
# Cost after iteration 2961: 0.265521
# Cost after iteration 2962: 0.236150
# Cost after iteration 2963: 0.229106
# Cost after iteration 2964: 0.211566
# Cost after iteration 2965: 0.203746
# Cost after iteration 2966: 0.196966
# Cost after iteration 2967: 0.194202
# Cost after iteration 2968: 0.192158
# Cost after iteration 2969: 0.191299
# Cost after iteration 2970: 0.190582
# Cost after iteration 2971: 0.190221
# Cost after iteration 2972: 0.189895
# Cost after iteration 2973: 0.189693
# Cost after iteration 2974: 0.189507
# Cost after iteration 2975: 0.189371
# Cost after iteration 2976: 0.189243
# Cost after iteration 2977: 0.189137
# Cost after iteration 2978: 0.189037
# Cost after iteration 2979: 0.188948
# Cost after iteration 2980: 0.188863
# Cost after iteration 2981: 0.188784
# Cost after iteration 2982: 0.188709
# Cost after iteration 2983: 0.188638
# Cost after iteration 2984: 0.188570
# Cost after iteration 2985: 0.188504
# Cost after iteration 2986: 0.188441
# Cost after iteration 2987: 0.188381
# Cost after iteration 2988: 0.188322
# Cost after iteration 2989: 0.188266
# Cost after iteration 2990: 0.188211
# Cost after iteration 2991: 0.188158
# Cost after iteration 2992: 0.188107
# Cost after iteration 2993: 0.188057
# Cost after iteration 2994: 0.188009
# Cost after iteration 2995: 0.187962
# Cost after iteration 2996: 0.187917
# Cost after iteration 2997: 0.187873
# Cost after iteration 2998: 0.187830
# Cost after iteration 2999: 0.187789
# W1 = [[-1.99993163  1.77545537]
#  [-2.30951924  2.01444067]]
# b1 = [[ 4.8399708 ]
#  [-6.36376486]]
# W2 = [[ 7.240852   -7.09393269]]
# b2 = [[-3.54495463]]

# %% [markdown]
# The final model parameters can be used to find the boundary line and for making predictions.

# %% [markdown]
# Computes probabilities using forward propagation, and make classification to 0/1 using 0.5 as the threshold.

# %%
def predict(X, parameters):
    """
    Using the learned parameters, predicts a class for each example in X
    
    Arguments:
    parameters -- python dictionary containing your parameters 
    X -- input data of size (n_x, m)
    
    Returns
    predictions -- vector of predictions of our model (blue: 0 / red: 1)
    """
    A2, cache = forward_propagation(X, parameters)
    predictions = (A2 > 0.5).astype(int)
    return predictions

# %%
X_pred = np.array([[2, 8, 2, 8], [2, 8, 8, 2]])
Y_pred = predict(X_pred, parameters)

print(f"Coordinates (in the columns):\n{X_pred}")
print(f"Predictions:\n{Y_pred}")
# Out:
# Coordinates (in the columns):
# [[2 8 2 8]
#  [2 8 8 2]]
# Predictions:
# [[1 1 0 0]]

# %%
def plot_decision_boundary(predict, parameters, X, Y):
    # Define bounds of the domain.
    min1, max1 = X[0, :].min()-1, X[0, :].max()+1
    min2, max2 = X[1, :].min()-1, X[1, :].max()+1
    # Define the x and y scale.
    x1grid = np.arange(min1, max1, 0.1)
    x2grid = np.arange(min2, max2, 0.1)
    # Create all of the lines and rows of the grid.
    xx, yy = np.meshgrid(x1grid, x2grid)
    # Flatten each grid to a vector.
    r1, r2 = xx.flatten(), yy.flatten()
    r1, r2 = r1.reshape((1, len(r1))), r2.reshape((1, len(r2)))
    # Vertical stack vectors to create x1,x2 input for the model.
    grid = np.vstack((r1,r2))
    # Make predictions for the grid.
    predictions = predict(grid, parameters)
    # Reshape the predictions back into a grid.
    zz = predictions.reshape(xx.shape)
    # Plot the grid of x, y and z values as a surface.
    plt.contourf(xx, yy, zz, cmap=plt.cm.Spectral.reversed())
    plt.scatter(X[0, :], X[1, :], c=Y, cmap=colors.ListedColormap(['blue', 'red']));

# Plot the decision boundary.
plot_decision_boundary(predict, parameters, X, Y)
plt.title("Decision Boundary for hidden layer size " + str(n_h))
# Out:
# Text(0.5, 1.0, 'Decision Boundary for hidden layer size 2')

# %% [markdown]
# Build a slightly different dataset:

# %%
n_samples = 2000
samples, labels = make_blobs(n_samples=n_samples, 
                             centers=([2.5, 3], [6.7, 7.9], [2.1, 7.9], [7.4, 2.8]), 
                             cluster_std=1.1,
                             random_state=0)
labels[(labels == 0)] = 0
labels[(labels == 1)] = 1
labels[(labels == 2) | (labels == 3)] = 1
X_2 = np.transpose(samples)
Y_2 = labels.reshape((1,n_samples))

plt.scatter(X_2[0, :], X_2[1, :], c=Y_2, cmap=colors.ListedColormap(['blue', 'red']));

# %%
# parameters_2 = nn_model(X_2, Y_2, n_h=1, num_iterations=3000, learning_rate=1.2, print_cost=False)
# use 4 hidden layers
parameters_2 = nn_model(X_2, Y_2, n_h=4, num_iterations=3000, learning_rate=1.2, print_cost=False)
# parameters_2 = nn_model(X_2, Y_2, n_h=15, num_iterations=3000, learning_rate=1.2, print_cost=False)

# This function will call predict function 
plot_decision_boundary(predict, parameters_2, X_2, Y_2)
plt.title("Decision Boundary")
# Out:
# Text(0.5, 1.0, 'Decision Boundary')

# %% [markdown]
# We can see that there are some misclassified points - real-world datasets are usually linearly inseparable, and there will be a small percentage of errors. More than that, we do not want to build a model that fits too closely, almost exactly to a particular set of data - it may fail to predict future observations. This problem is known as **overfitting**.
